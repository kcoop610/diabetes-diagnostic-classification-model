# %% [markdown]
# <img src='./images/head_image3.jpg' align='right'>

# %% [markdown]
# # Predicting Diabetes Diagnosis

# %% [markdown]
# In 2015, diabetes was the seventh leading cause of death in the United States.  More than 30 million Americans are living with diabetes, and 86 million are living with prediabetes, which is a serious health condition that increases a person’s risk of type 2 diabetes and other chronic diseases. The prevalence of diabetes and overweight (one of the major risk factors for diabetes) continue to increase. Substantial new efforts to prevent or control diabetes have begun, including the Diabetes Prevention Trial and the National Diabetes Education Program.
#
# Diabetes is diagnosed by Glycated Hemoglobin (A1C) levels, which indicate a person's blood sugar levels and are measured via a blood test. However, many organizations aiming to prevent diabetes and other chronic conditions such as public health agencies and insurance providers don't have access to this sensitive information.
#
# **This report seeks to predict the presence of diabetes or prediabetes using only information that could be gathered by a survey or basic body measurements.**
#
# **Using this model, stakeholders invested in public health can target participants in health and wellness programs which aim to reverse prediabetes, prevent diabetes, and manage the disease.**
#
# Potential stakeholders:
# - Public health agencies
# - Insurance companies
# - Employer benefits coordinators
# - Health & wellness companies

# %% [markdown]
# # Data Source
#
# <img src='./images/nhanes.jpg' align='center'>

# %% [markdown]
# ## National Health and Nutrition Examination Survey (NHANES)
#
# The [National Health and Nutrition Examination Survey (NHANES)](https://www.cdc.gov/nchs/nhanes/about_nhanes.htm) is a program of continuous studies designed to assess the health and nutritional status of adults and children in the United States. The survey examines a nationally representative sample of about 5,000 persons located across the country each year. The survey is unique in that it combines interviews and physical examinations. The NHANES interview includes demographic, socioeconomic, dietary, and health-related questions. The examination component consists of medical, dental, and physiological measurements, as well as laboratory tests administered by highly trained medical personnel.
#
# NHANES is a major program of the National Center for Health Statistics (NCHS). NCHS is part of the Centers for Disease Control and Prevention (CDC) and has the responsibility for producing vital and health statistics for the Nation.
#
# ## Subset for Classification Model
#
# While NHANES collects a wealth of demographic, laboratory, and medical data, this analysis and classification model uses a subset comprised of:
#
# * **Demographics, Smoking, Physical Activity** - surveys collected by trained interviewers using Computer-Assisted Personal Interview (CAPI) system in either English or Spanish, sometimes with assistance from an interpreter
#
# * **Body Measures** - measured by trained health technicians in the Mobile Examination Center (MEC)
#
# * **Pulse** - three oscillometric pulse readings were recorded by trained health technicians, then averaged together for a single representative pulse measurement
#
# * **A1C** - whole blood specimens were processed, stored, and shipped to the University of Missouri-Columbia, MO for analysis.
#
# Diabetes/prediabetes diagnosis was calculated based on the A1C level using the Mayo Clinic's guidelines.
#
#
#
# As is typical for survey data, there are some filler responses such as "don't know" and "refused" in addition to null values. Each of these were evaluated, and one of the following steps was taken:
# - Filled nulls/fillers with an assumed response if the number of responses in this class is low and there was a straightforward "safe" assumption. For example, "don't know" response to question about military service was assumed to be a "no."
# - Created a "no_answer" class if the lack of clear answer seemed to potentially inicate some relevant finding. For example, if a person responded "don't know" to health insurance coverage, this may be a relevant predictor of their health.
# - Replaced with a null value, to be addressed using an intelligent imputer method later in the process after the data has been split into training and testing samples.

# %%
import pandas as pd
pd.set_option('display.max_columns', 0)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# styling notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
# body {
#     font-family:'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     background-color: rgb(231, 231, 231);
# }
# h1 {
#     color: white;
#     background-color: rgb(108, 30, 185);
#     padding: 3mm;
#     font-size: x-large;
# }
# h2 {
#     color: mediumpurple;
# }
#
# h3 {
#     color: cornflowerblue
# }
#
# h4 {
#     color: rgb(99, 127, 202)
# }
#
# </style>

# %%
demographic = pd.read_sas('./data/NHANES2017-2018_demographic.xpt')
insurance = pd.read_sas('./data/NHANES2017-2018_insurance.xpt')
measures = pd.read_sas('./data/NHANES2017-2018_body_measures.xpt')
activity = pd.read_sas('./data/NHANES2017-2018_physical_activity.xpt')
smoking = pd.read_sas('./data/NHANES2017-2018_smoking.xpt')
bp = pd.read_sas('./data/NHANES2017-2018_blood_pressure_oscillometric.xpt')
a1c = pd.read_sas('./data/NHANES2017-2018_a1c.xpt')

# Datasets considered, but not used for this model
# chol_total = pd.read_sas('./data/NHANES2017-2018_total_cholesterol.xpt')
# chol_hdl = pd.read_sas('./data/NHANES2017-2018_hdl_cholesterol.xpt')
# chol_ldl = pd.read_sas('./data/NHANES2017-2018_ldl_cholesterol.xpt')
# insulin = pd.read_sas('./data/NHANES2017-2018_insulin.xpt')

# %%
data = [a1c, demographic, insurance, measures, activity, smoking, bp]

# %%
for f in data:
    f.SEQN = f.SEQN.map(lambda x: int(x))
    f.set_index('SEQN', inplace=True)
    display(f.info())
    print('*****'*15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6401 entries, 93705 to 102956
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LBXGH   6045 non-null   float64
# dtypes: float64(1)
# memory usage: 100.0 KB
# None
# ***************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9254 entries, 93703 to 102956
# Data columns (total 45 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SDDSRVYR  9254 non-null   float64
#  1   RIDSTATR  9254 non-null   float64
#  2   RIAGENDR  9254 non-null   float64
#  3   RIDAGEYR  9254 non-null   float64
#  4   RIDAGEMN  597 non-null    float64
#  5   RIDRETH1  9254 non-null   float64
#  6   RIDRETH3  9254 non-null   float64
#  7   RIDEXMON  8704 non-null   float64
#  8   RIDEXAGM  3433 non-null   float64
#  9   DMQMILIZ  6004 non-null   float64
#  10  DMQADFC   561 non-null    float64
#  11  DMDBORN4  9254 non-null   float64
#  12  DMDCITZN  9251 non-null   float64
#  13  DMDYRSUS  1948 non-null   float64
#  14  DMDEDUC3  2306 non-null   float64
#  15  DMDEDUC2  5569 non-null   float64
#  16  DMDMARTL  5569 non-null   float64
#  17  RIDEXPRG  1110 non-null   float64
#  18  SIALANG   9254 non-null   float64
#  19  SIAPROXY  9254 non-null   float64
#  20  SIAINTRP  9254 non-null   float64
#  21  FIALANG   8780 non-null   float64
#  22  FIAPROXY  8780 non-null   float64
#  23  FIAINTRP  8780 non-null   float64
#  24  MIALANG   6684 non-null   float64
#  25  MIAPROXY  6684 non-null   float64
#  26  MIAINTRP  6684 non-null   float64
#  27  AIALANGA  4977 non-null   float64
#  28  DMDHHSIZ  9254 non-null   float64
#  29  DMDFMSIZ  9254 non-null   float64
#  30  DMDHHSZA  9254 non-null   float64
#  31  DMDHHSZB  9254 non-null   float64
#  32  DMDHHSZE  9254 non-null   float64
#  33  DMDHRGND  9254 non-null   float64
#  34  DMDHRAGZ  9254 non-null   float64
#  35  DMDHREDZ  8764 non-null   float64
#  36  DMDHRMAZ  9063 non-null   float64
#  37  DMDHSEDZ  4751 non-null   float64
#  38  WTINT2YR  9254 non-null   float64
#  39  WTMEC2YR  9254 non-null   float64
#  40  SDMVPSU   9254 non-null   float64
#  41  SDMVSTRA  9254 non-null   float64
#  42  INDHHIN2  8763 non-null   float64
#  43  INDFMIN2  8780 non-null   float64
#  44  INDFMPIR  8023 non-null   float64
# dtypes: float64(45)
# memory usage: 3.2 MB
# None
# ***************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9254 entries, 93703 to 102956
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   HIQ011    9254 non-null   float64
#  1   HIQ031A   4254 non-null   float64
#  2   HIQ031B   1582 non-null   float64
#  3   HIQ031C   58 non-null     float64
#  4   HIQ031D   2527 non-null   float64
#  5   HIQ031E   93 non-null     float64
#  6   HIQ031F   295 non-null    float64
#  7   HIQ031H   533 non-null    float64
#  8   HIQ031I   301 non-null    float64
#  9   HIQ031J   708 non-null    float64
#  10  HIQ031AA  1 non-null      float64
#  11  HIQ260    172 non-null    float64
#  12  HIQ105    1141 non-null   float64
#  13  HIQ270    8171 non-null   float64
#  14  HIQ210    8171 non-null   float64
# dtypes: float64(15)
# memory usage: 1.1 MB
# None
# ***************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8704 entries, 93703 to 102956
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BMDSTATS  8704 non-null   float64
#  1   BMXWT     8580 non-null   float64
#  2   BMIWT     416 non-null    float64
#  3   BMXRECUM  894 non-null    float64
#  4   BMIRECUM  24 non-null     float64
#  5   BMXHEAD   194 non-null    float64
#  6   BMIHEAD   0 non-null      float64
#  7   BMXHT     8016 non-null   float64
#  8   BMIHT     99 non-null     float64
#  9   BMXBMI    8005 non-null   float64
#  10  BMXLEG    6703 non-null   float64
#  11  BMILEG    334 non-null    float64
#  12  BMXARML   8177 non-null   float64
#  13  BMIARML   347 non-null    float64
#  14  BMXARMC   8173 non-null   float64
#  15  BMIARMC   350 non-null    float64
#  16  BMXWAIST  7601 non-null   float64
#  17  BMIWAIST  437 non-null    float64
#  18  BMXHIP    6039 non-null   float64
#  19  BMIHIP    270 non-null    float64
# dtypes: float64(20)
# memory usage: 1.4 MB
# None
# ***************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5856 entries, 93705 to 102956
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PAQ605  5856 non-null   float64
#  1   PAQ610  1389 non-null   float64
#  2   PAD615  1381 non-null   float64
#  3   PAQ620  5856 non-null   float64
#  4   PAQ625  2439 non-null   float64
#  5   PAD630  2426 non-null   float64
#  6   PAQ635  5856 non-null   float64
#  7   PAQ640  1439 non-null   float64
#  8   PAD645  1430 non-null   float64
#  9   PAQ650  5856 non-null   float64
#  10  PAQ655  1434 non-null   float64
#  11  PAD660  1431 non-null   float64
#  12  PAQ665  5856 non-null   float64
#  13  PAQ670  2308 non-null   float64
#  14  PAD675  2301 non-null   float64
#  15  PAD680  5846 non-null   float64
# dtypes: float64(16)
# memory usage: 777.8 KB
# None
# ***************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6724 entries, 93705 to 102956
# Data columns (total 36 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SMQ020    5856 non-null   float64
#  1   SMD030    2359 non-null   float64
#  2   SMQ040    2359 non-null   float64
#  3   SMQ050Q   1338 non-null   float64
#  4   SMQ050U   1255 non-null   float64
#  5   SMD057    1338 non-null   float64
#  6   SMQ078    793 non-null    float64
#  7   SMD641    1063 non-null   float64
#  8   SMD650    1022 non-null   float64
#  9   SMD093    1021 non-null   float64
#  10  SMDUPCA   6724 non-null   object
#  11  SMD100BR  6724 non-null   object
#  12  SMD100FL  929 non-null    float64
#  13  SMD100MN  929 non-null    float64
#  14  SMD100LN  929 non-null    float64
#  15  SMD100TR  695 non-null    float64
#  16  SMD100NI  695 non-null    float64
#  17  SMD100CO  695 non-null    float64
#  18  SMQ621    821 non-null    float64
#  19  SMD630    42 non-null     float64
#  20  SMQ661    14 non-null     float64
#  21  SMQ665A   3 non-null      float64
#  22  SMQ665B   1 non-null      float64
#  23  SMQ665C   4 non-null      float64
#  24  SMQ665D   2 non-null      float64
#  25  SMQ670    1035 non-null   float64
#  26  SMQ848    528 non-null    float64
#  27  SMQ852Q   522 non-null    float64
#  28  SMQ852U   519 non-null    float64
#  29  SMQ890    5856 non-null   float64
#  30  SMQ895    2095 non-null   float64
#  31  SMQ900    5856 non-null   float64
#  32  SMQ905    1150 non-null   float64
#  33  SMQ910    5856 non-null   float64
#  34  SMQ915    861 non-null    float64
#  35  SMAQUEX2  6724 non-null   float64
# dtypes: float64(34), object(2)
# memory usage: 1.9+ MB
# None
# ***************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7132 entries, 93705 to 102956
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BPAOARM   7132 non-null   object
#  1   BPAOCSZ   6144 non-null   float64
#  2   BPAOMNTS  6144 non-null   float64
#  3   BPXOSY1   6143 non-null   float64
#  4   BPXODI1   6143 non-null   float64
#  5   BPXOSY2   6123 non-null   float64
#  6   BPXODI2   6123 non-null   float64
#  7   BPXOSY3   6094 non-null   float64
#  8   BPXODI3   6094 non-null   float64
#  9   BPXOPLS1  5262 non-null   float64
#  10  BPXOPLS2  5244 non-null   float64
#  11  BPXOPLS3  5220 non-null   float64
# dtypes: float64(11), object(1)
# memory usage: 724.3+ KB
# None
# ***************************************************************************

# %% [markdown]
# ### Demographics
#
# [View source for additional description and details](https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DEMO_J.htm)
#
# The demographics file contains information about the individual respondent, their family, and their household, including age, gender, race, education level, marital status, military service status, country of birth, US citizenship, household and family composition and income.

# %%
demographic.describe().round(1)
# Out:
#        SDDSRVYR  RIDSTATR  RIAGENDR  ...  INDHHIN2  INDFMIN2  INDFMPIR
# count    9254.0    9254.0    9254.0  ...    8763.0    8780.0    8023.0
# mean       10.0       1.9       1.5  ...      12.5      12.2       2.4
# std         0.0       0.2       0.5  ...      17.3      17.2       1.6
# min        10.0       1.0       1.0  ...       1.0       1.0       0.0
# 25%        10.0       2.0       1.0  ...       6.0       6.0       1.0
# 50%        10.0       2.0       2.0  ...       8.0       8.0       1.9
# 75%        10.0       2.0       2.0  ...      14.0      14.0       3.7
# max        10.0       2.0       2.0  ...      99.0      99.0       5.0
#
# [8 rows x 45 columns]

# %%
demographic.columns
# Out:
# Index(['SDDSRVYR', 'RIDSTATR', 'RIAGENDR', 'RIDAGEYR', 'RIDAGEMN', 'RIDRETH1',
#        'RIDRETH3', 'RIDEXMON', 'RIDEXAGM', 'DMQMILIZ', 'DMQADFC', 'DMDBORN4',
#        'DMDCITZN', 'DMDYRSUS', 'DMDEDUC3', 'DMDEDUC2', 'DMDMARTL', 'RIDEXPRG',
#        'SIALANG', 'SIAPROXY', 'SIAINTRP', 'FIALANG', 'FIAPROXY', 'FIAINTRP',
#        'MIALANG', 'MIAPROXY', 'MIAINTRP', 'AIALANGA', 'DMDHHSIZ', 'DMDFMSIZ',
#        'DMDHHSZA', 'DMDHHSZB', 'DMDHHSZE', 'DMDHRGND', 'DMDHRAGZ', 'DMDHREDZ',
#        'DMDHRMAZ', 'DMDHSEDZ', 'WTINT2YR', 'WTMEC2YR', 'SDMVPSU', 'SDMVSTRA',
#        'INDHHIN2', 'INDFMIN2', 'INDFMPIR'],
#       dtype='object')

# %% [markdown]
# After reviewing the source documentation, only a handful of features which are easily interpretable and may be relevant to predicting diabetes/prediabetes were kept for analysis.

# %%
keepcols_demographic = ['RIAGENDR', 'RIDAGEYR', 'RIDRETH3', 'DMQMILIZ', 'DMDBORN4', 'DMDCITZN',
                    'DMDEDUC2', 'DMDMARTL', 'RIDEXPRG', 'DMDHHSIZ', 'INDHHIN2', 'INDFMPIR']

# %%
keep_demographic = demographic.copy()[keepcols_demographic]
keep_demographic.rename(mapper={'RIAGENDR': 'gender',
                                'RIDAGEYR': 'age',
                                'RIDRETH3': 'race',
                                'DMQMILIZ': 'veteran_status',
                                'DMDBORN4': 'country_of_birth',
                                'DMDCITZN': 'citizen_status',
                                'DMDEDUC2': 'education',
                                'DMDMARTL': 'marital_status',
                                'RIDEXPRG': 'pregnancy_status',
                                'INDHHIN2': 'annual_household_income',
                                'INDFMPIR': 'income_poverty_ratio',
                                'DMDHHSIZ': 'household_size'}, 
                       axis=1, inplace=True)
keep_demographic.head()
# Out:
#        gender   age  ...  annual_household_income  income_poverty_ratio
# SEQN                 ...
# 93703     2.0   2.0  ...                     15.0                  5.00
# 93704     1.0   2.0  ...                     15.0                  5.00
# 93705     2.0  66.0  ...                      3.0                  0.82
# 93706     1.0  18.0  ...                      NaN                   NaN
# 93707     1.0  13.0  ...                     10.0                  1.88
#
# [5 rows x 12 columns]

# %%
keep_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9254 entries, 93703 to 102956
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gender                   9254 non-null   float64
#  1   age                      9254 non-null   float64
#  2   race                     9254 non-null   float64
#  3   veteran_status           6004 non-null   float64
#  4   country_of_birth         9254 non-null   float64
#  5   citizen_status           9251 non-null   float64
#  6   education                5569 non-null   float64
#  7   marital_status           5569 non-null   float64
#  8   pregnancy_status         1110 non-null   float64
#  9   household_size           9254 non-null   float64
#  10  annual_household_income  8763 non-null   float64
#  11  income_poverty_ratio     8023 non-null   float64
# dtypes: float64(12)
# memory usage: 939.9 KB

# %% [markdown]
# Questionnaire responses are coded, which makes interpretation difficult. The following cells explore each feature, decode values, and decipher response options.

# %%
keep_demographic['gender'].value_counts(dropna=False)
# Out:
# 2.0    4697
# 1.0    4557
# Name: gender, dtype: int64

# %%
keep_demographic['gender'].replace({1.0: 'male', 2.0: 'female'}, inplace=True)

# %%
keep_demographic['gender'].value_counts(dropna=False)
# Out:
# female    4697
# male      4557
# Name: gender, dtype: int64

# %%
keep_demographic['age'].describe().round(2)
# Out:
# count    9254.00
# mean       34.33
# std        25.50
# min         0.00
# 25%        11.00
# 50%        31.00
# 75%        58.00
# max        80.00
# Name: age, dtype: float64

# %% [markdown]
# *Note - Individuals aged 80 and over are topcoded at 80. In NHANES 2017-2018, the weighted mean age for participants 80+ is 85*

# %%
keep_demographic['age'] = keep_demographic['age'].astype(int)

# %% [markdown]
# This model focuses on adults age 18+.

# %%
# remove if age less than 18
keep_demographic = keep_demographic[keep_demographic['age']>=18]

# %%
keep_demographic['age'].describe().astype(int)
# Out:
# count    5856
# mean       49
# std        18
# min        18
# 25%        33
# 50%        51
# 75%        65
# max        80
# Name: age, dtype: int64

# %%
keep_demographic['race'].value_counts(dropna=False)
# Out:
# 3.0    2032
# 4.0    1343
# 6.0     849
# 1.0     792
# 2.0     543
# 7.0     297
# Name: race, dtype: int64

# %%
keep_demographic['race'].replace({1.0: 'mexican_american',
                                  2.0: 'hispanic',
                                  3.0: 'white',
                                  4.0: 'black',
                                  6.0: 'asian',
                                  7.0: 'other'}, 
                                 inplace=True)

# %%
keep_demographic['race'].value_counts(dropna=False)
# Out:
# white               2032
# black               1343
# asian                849
# mexican_american     792
# hispanic             543
# other                297
# Name: race, dtype: int64

# %%
keep_demographic['veteran_status'].value_counts(dropna=False)
# Out:
# 2.0    5292
# 1.0     561
# 7.0       2
# 9.0       1
# Name: veteran_status, dtype: int64

# %%
keep_demographic['veteran_status'].replace({1.0: 'yes',
                                            2.0: 'no',
                                            7.0: 'no',
                                            9.0: 'no',}, 
                                           inplace=True)

# %%
keep_demographic['veteran_status'].value_counts(dropna=False)
# Out:
# no     5295
# yes     561
# Name: veteran_status, dtype: int64

# %%
keep_demographic['country_of_birth'].value_counts(dropna=False)
# Out:
# 1.0     4067
# 2.0     1786
# 77.0       2
# 99.0       1
# Name: country_of_birth, dtype: int64

# %%
keep_demographic['country_of_birth'].replace({1.0: 'usa',
                                              2.0: 'other',
                                              77.0: 'usa',
                                              99.0: 'usa'}, 
                                             inplace=True)

# %%
keep_demographic['country_of_birth'].value_counts(dropna=False)
# Out:
# usa      4070
# other    1786
# Name: country_of_birth, dtype: int64

# %%
keep_demographic['citizen_status'].value_counts(dropna=False)
# Out:
# 1.0    5030
# 2.0     801
# 7.0      15
# 9.0       7
# NaN       3
# Name: citizen_status, dtype: int64

# %%
# kept a "no_answer" class since this may be meaningful
keep_demographic['citizen_status'].replace({1.0: 'citizen',
                                            2.0: 'non_citizen',
                                            7.0: 'no_answer',
                                            9.0: 'no_answer',
                                            np.nan: 'no_answer'}, 
                                           inplace=True)

# %%
keep_demographic['education'].value_counts(dropna=False)
# Out:
# 4.0    1778
# 5.0    1336
# 3.0    1325
# 2.0     638
# 1.0     479
# NaN     287
# 9.0      11
# 7.0       2
# Name: education, dtype: int64

# %%
# these nulls are not as easy to fill in, so I'll use an imputer at a later step
keep_demographic['education'].replace({1.0: 'no_diploma',
                                       2.0: 'no_diploma',
                                       3.0: 'highschool_grad',
                                       4.0: 'some_college',
                                       5.0: 'college_grad',
                                       7.0: np.nan,
                                       9.0: np.nan}, inplace=True)

# %%
keep_demographic['marital_status'].value_counts(dropna=False)
# Out:
# 1.0     2737
# 5.0     1006
# 3.0      641
# 6.0      515
# 2.0      462
# NaN      287
# 4.0      202
# 77.0       6
# Name: marital_status, dtype: int64

# %%
keep_demographic['marital_status'].replace({1.0: 'married or living with partner',
                                            2.0: 'widowed',
                                            3.0: 'divorced/separated',
                                            4.0: 'divorced/separated',
                                            5.0: 'never married',
                                            6.0: 'married or living with partner',
                                            77.0: 'no_answer'}, inplace=True)

# %%
keep_demographic[keep_demographic['marital_status'].isna()].sort_values('age')
# Out:
#         gender  age  ... annual_household_income income_poverty_ratio
# SEQN                 ...
# 93706     male   18  ...                     NaN                  NaN
# 98618     male   18  ...                     3.0                 0.52
# 98695     male   18  ...                    12.0                  NaN
# 98697     male   18  ...                    15.0                 5.00
# 98829     male   18  ...                    15.0                 3.85
# ...        ...  ...  ...                     ...                  ...
# 98866     male   19  ...                     1.0                 0.37
# 95585     male   19  ...                    14.0                 3.88
# 98938   female   19  ...                    13.0                  NaN
# 99013   female   19  ...                     7.0                 1.52
# 102837  female   19  ...                     1.0                 0.17
#
# [287 rows x 12 columns]

# %% [markdown]
# All null values in the marital status column are 18 or 19 year olds, so I will fill the nulls with "never married."

# %%
keep_demographic['marital_status'].fillna('never married', inplace=True)

# %%
keep_demographic['marital_status'].value_counts(dropna=False)
# Out:
# married or living with partner    3252
# never married                     1293
# divorced/separated                 843
# widowed                            462
# no_answer                            6
# Name: marital_status, dtype: int64

# %%
keep_demographic['pregnancy_status'].value_counts(dropna=False)
# Out:
# NaN    4746
# 2.0     966
# 3.0      89
# 1.0      55
# Name: pregnancy_status, dtype: int64

# %% [markdown]
# Per the data source, respondents were coded with a value 3 "could not be determined" if (1) the respondent reported did not know her pregnancy status and the urine test was negative, or (2) if the respondent was interviewed but not examined
#
# Because the urine test was negative in first scenario, the responded is assumed to be not pregnant.
#
# Respondents who fall into the second scenario will be removed from the sample later on when data files are merged, as it's likely that the "examination" would have also included the A1C test. Because this is a supervised learning activity, only respondents with valid A1C levels will be kept in the sample.
#
# Null values are assumed to indicate "not pregnant".
#
# Because pregnancy may cause fluctuations in weight and body measurements, respondents who are pregnant are dropped from the sample.

# %%
keep_demographic = keep_demographic[keep_demographic['pregnancy_status'] != 1.0]

# %%
keep_demographic.drop(columns='pregnancy_status', inplace=True)

# %%
keep_demographic.head()
# Out:
#        gender  age  ... annual_household_income income_poverty_ratio
# SEQN                ...
# 93705  female   66  ...                     3.0                 0.82
# 93706    male   18  ...                     NaN                  NaN
# 93708  female   66  ...                     6.0                 1.63
# 93709  female   75  ...                     2.0                 0.41
# 93711    male   56  ...                    15.0                 5.00
#
# [5 rows x 11 columns]

# %% [markdown]
# While multiple income-related questions were surveyed, the feature most meaningful for this model is annual household income. This number would include the combined incomes of all members of a household, which may be comprised of a single family/individual, more than one family, more than one unrelated individuals, or any combination.
#
# Income ranges were captured as the response to this question. In order to create a continuous numeric variable, these ranges were replaced with the highest number in the range for purposes of this model. For example, a household reporting annual income between 45,000 and 54,999 was recoded to 55,000. The 100k+ category was coded as 150,000.
#
# Some respondents only reported whether their income was under 20k (197 total respondents), or above 20k (69 total respondents). Those reponding <20k were recoded as 15,000 since this is likely a larger range with more actual values falling below the maximum. Those responding >20k were recoded as 45,000.

# %%
keep_demographic['annual_household_income'].value_counts(dropna=False)
# Out:
# 15.0    988
# 6.0     574
# 7.0     570
# 14.0    497
# 8.0     389
# NaN     345
# 5.0     344
# 4.0     335
# 9.0     331
# 10.0    277
# 3.0     264
# 12.0    220
# 2.0     164
# 1.0     164
# 99.0    143
# 77.0    121
# 13.0     75
# Name: annual_household_income, dtype: int64

# %%
# these nulls are not as easy to fill in, so I'll use an imputer at a later step
keep_demographic['annual_household_income'].replace({1.0: 5000,
                                                     2.0: 10000,
                                                     3.0: 15000,
                                                     4.0: 20000,
                                                     5.0: 25000,
                                                     6.0: 35000,
                                                     7.0: 45000,
                                                     8.0: 55000,
                                                     9.0: 65000,
                                                     10.0: 75000,
                                                     12.0: 15000,
                                                     13.0: 45000,
                                                     14.0: 100000,
                                                     15.0: 150000,
                                                     77.0: np.nan,
                                                     99.0: np.nan}, inplace=True)

# %%
keep_demographic['annual_household_income'].value_counts(dropna=False)
# Out:
# 150000.0    988
# 45000.0     645
# NaN         609
# 35000.0     574
# 100000.0    497
# 15000.0     484
# 55000.0     389
# 25000.0     344
# 20000.0     335
# 65000.0     331
# 75000.0     277
# 5000.0      164
# 10000.0     164
# Name: annual_household_income, dtype: int64

# %%
keep_demographic['household_size'].value_counts(dropna=False)
# Out:
# 2.0    1787
# 3.0    1057
# 4.0     918
# 1.0     806
# 5.0     638
# 6.0     334
# 7.0     261
# Name: household_size, dtype: int64

# %%
keep_demographic['household_size'] = keep_demographic['household_size'].astype(int)

# %%
keep_demographic['income_poverty_ratio'].describe().round(2)
# Out:
# count    4975.00
# mean        2.52
# std         1.61
# min         0.00
# 25%         1.18
# 50%         2.08
# 75%         4.06
# max         5.00
# Name: income_poverty_ratio, dtype: float64

# %%
keep_demographic['income_poverty_ratio'].isna().sum()
# Out:
# 826

# %% [markdown]
# Per the data source:
# > Income-Poverty Ratio was calculated by dividing family (or individual) income by the poverty guidelines specific to the survey year. The value was not computed if the respondent only reported income as < 20,000 or ≥ 20,000. If family income was reported as a more detailed category, the midpoint of the range was used to compute the ratio. Values at or above 5.00 were coded as 5.00 or more because of disclosure concerns. The values were not computed if the income data was missing.

# %%
keep_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5801 entries, 93705 to 102956
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gender                   5801 non-null   object
#  1   age                      5801 non-null   int64
#  2   race                     5801 non-null   object
#  3   veteran_status           5801 non-null   object
#  4   country_of_birth         5801 non-null   object
#  5   citizen_status           5801 non-null   object
#  6   education                5501 non-null   object
#  7   marital_status           5801 non-null   object
#  8   household_size           5801 non-null   int64
#  9   annual_household_income  5192 non-null   float64
#  10  income_poverty_ratio     4975 non-null   float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 543.8+ KB

# %% [markdown]
# ### Health Insurance
#
# [View source for additional description and details](https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/HIQ_J.htm)
#
# The Health Insurance questionnaire provides respondent-level interview data on insurance coverage, type of insurance coverage, coverage of prescription drugs, and uninsured status during the past 12 months.

# %%
insurance
# Out:
#         HIQ011  HIQ031A  HIQ031B  HIQ031C  ...  HIQ260  HIQ105  HIQ270  HIQ210
# SEQN                                       ...
# 93703      1.0     14.0      NaN      NaN  ...     NaN     NaN     1.0     2.0
# 93704      1.0     14.0      NaN      NaN  ...     NaN     NaN     1.0     2.0
# 93705      1.0      NaN     15.0      NaN  ...     NaN     1.0     1.0     2.0
# 93706      1.0     14.0      NaN      NaN  ...     NaN     NaN     1.0     2.0
# 93707      1.0      NaN      NaN      NaN  ...     NaN     NaN     1.0     2.0
# ...        ...      ...      ...      ...  ...     ...     ...     ...     ...
# 102952     1.0     14.0     15.0      NaN  ...     NaN     1.0     1.0     2.0
# 102953     1.0     14.0      NaN      NaN  ...     NaN     NaN     1.0     1.0
# 102954     1.0      NaN      NaN      NaN  ...     NaN     NaN     1.0     2.0
# 102955     1.0     14.0      NaN      NaN  ...     NaN     NaN     1.0     1.0
# 102956     1.0      NaN      NaN      NaN  ...     NaN     NaN     1.0     2.0
#
# [9254 rows x 15 columns]

# %%
insurance.columns
# Out:
# Index(['HIQ011', 'HIQ031A', 'HIQ031B', 'HIQ031C', 'HIQ031D', 'HIQ031E',
#        'HIQ031F', 'HIQ031H', 'HIQ031I', 'HIQ031J', 'HIQ031AA', 'HIQ260',
#        'HIQ105', 'HIQ270', 'HIQ210'],
#       dtype='object')

# %%
keepcols_insurance = ['HIQ011', 'HIQ031A', 'HIQ031B', 'HIQ031C', 'HIQ031D', 'HIQ031E',
       'HIQ031F', 'HIQ031H', 'HIQ031I', 'HIQ031J', 'HIQ031AA', 'HIQ270', 'HIQ210']

mapper_insurance = {'HIQ011': 'coverage_status',
          'HIQ031A': 'covered_private',
          'HIQ031B': 'covered_medicare',
          'HIQ031C': 'covered_medigap',
          'HIQ031D': 'covered_medicaid',
          'HIQ031E': 'covered_chip',
          'HIQ031F': 'covered_military',
          'HIQ031H': 'covered_state',
          'HIQ031I': 'covered_other_gov',
          'HIQ031J': 'covered_single_service',
          'HIQ031AA': 'not_covered',
          'HIQ270': 'prescription_coverage',
          'HIQ210': 'uninsured_in_last_year'}

# %%
keep_insurance = insurance.copy()[keepcols_insurance]
keep_insurance.rename(mapper=mapper_insurance, axis=1, inplace=True)
keep_insurance
# Out:
#         coverage_status  ...  uninsured_in_last_year
# SEQN                     ...
# 93703               1.0  ...                     2.0
# 93704               1.0  ...                     2.0
# 93705               1.0  ...                     2.0
# 93706               1.0  ...                     2.0
# 93707               1.0  ...                     2.0
# ...                 ...  ...                     ...
# 102952              1.0  ...                     2.0
# 102953              1.0  ...                     1.0
# 102954              1.0  ...                     2.0
# 102955              1.0  ...                     1.0
# 102956              1.0  ...                     2.0
#
# [9254 rows x 13 columns]

# %%
keep_insurance['coverage_status'].value_counts(dropna=False)
# Out:
# 1.0    8157
# 2.0    1072
# 9.0      18
# 7.0       7
# Name: coverage_status, dtype: int64

# %%
# kept a "no_answer" class as this may be meaningful
keep_insurance['coverage_status'].replace({1.0: 'insured',
                                   2.0: 'uninsured',
                                   7.0: 'no_answer',
                                   9.0: 'no_answer'}, inplace=True)

# %%
keep_insurance['coverage_status'].value_counts(dropna=False)
# Out:
# insured      8157
# uninsured    1072
# no_answer      25
# Name: coverage_status, dtype: int64

# %%
keep_insurance['covered_private'].value_counts(dropna=False)
# Out:
# NaN     5000
# 14.0    4188
# 99.0      63
# 77.0       3
# Name: covered_private, dtype: int64

# %%
keep_insurance['covered_private'].replace({14.0: 'yes',
                                   99.0: 'no',
                                   77.0: 'no',
                                   np.nan: 'no'}, inplace=True)

# %%
keep_insurance['covered_medicare'].value_counts(dropna=False)
# Out:
# NaN     7672
# 15.0    1582
# Name: covered_medicare, dtype: int64

# %%
keep_insurance['covered_medicare'].replace({15.0: 'yes', np.nan: 'no'}, inplace=True)

# %%
keep_insurance['covered_medigap'].value_counts(dropna=False)
# Out:
# NaN     9196
# 16.0      58
# Name: covered_medigap, dtype: int64

# %%
keep_insurance['covered_medigap'].replace({16.0: 'yes', np.nan: 'no'}, inplace=True)

# %%
keep_insurance['covered_medicaid'].value_counts(dropna=False)
# Out:
# NaN     6727
# 17.0    2527
# Name: covered_medicaid, dtype: int64

# %%
keep_insurance['covered_medicaid'].replace({17.0: 'yes', np.nan: 'no'}, inplace=True)

# %%
keep_insurance['covered_chip'].value_counts(dropna=False)
# Out:
# NaN     9161
# 18.0      93
# Name: covered_chip, dtype: int64

# %%
keep_insurance['covered_chip'].replace({18.0: 'yes', np.nan: 'no'}, inplace=True)

# %%
keep_insurance['covered_military'].value_counts(dropna=False)
# Out:
# NaN     8959
# 19.0     295
# Name: covered_military, dtype: int64

# %%
keep_insurance['covered_military'].replace({19.0: 'yes', np.nan: 'no'}, inplace=True)

# %%
keep_insurance['covered_state'].value_counts(dropna=False)
# Out:
# NaN     8721
# 21.0     533
# Name: covered_state, dtype: int64

# %%
keep_insurance['covered_state'].replace({21.0: 'yes', np.nan: 'no'}, inplace=True)

# %%
keep_insurance['covered_other_gov'].value_counts(dropna=False)
# Out:
# NaN     8953
# 22.0     301
# Name: covered_other_gov, dtype: int64

# %%
keep_insurance['covered_other_gov'].replace({22.0: 'yes', np.nan: 'no'}, inplace=True)

# %%
keep_insurance['covered_single_service'].value_counts(dropna=False)
# Out:
# NaN     8546
# 23.0     708
# Name: covered_single_service, dtype: int64

# %%
keep_insurance['covered_single_service'].replace({23.0: 'yes', np.nan: 'no'}, inplace=True)

# %%
keep_insurance['not_covered'].value_counts(dropna=False)
# Out:
# NaN     9253
# 40.0       1
# Name: not_covered, dtype: int64

# %%
#seems to be an anomoly, so I drop this row
keep_insurance[keep_insurance['not_covered']==40.0]
keep_insurance = keep_insurance[keep_insurance['not_covered']!=40.0]

# %%
# dropping the column since all values are now null
keep_insurance.drop(columns='not_covered', inplace=True)
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
keep_insurance.head()
# Out:
#       coverage_status  ... uninsured_in_last_year
# SEQN                   ...
# 93703         insured  ...                    2.0
# 93704         insured  ...                    2.0
# 93705         insured  ...                    2.0
# 93706         insured  ...                    2.0
# 93707         insured  ...                    2.0
#
# [5 rows x 12 columns]

# %%
keep_insurance['prescription_coverage'].value_counts(dropna=False)
# Out:
# 1.0    7678
# NaN    1082
# 2.0     379
# 9.0     110
# 7.0       4
# Name: prescription_coverage, dtype: int64

# %%
keep_insurance['prescription_coverage'].replace({1.0: 'yes',
                                         2.0: 'no',
                                         7.0: 'no_answer',
                                         9.0: 'no_answer',
                                         np.nan: 'no_answer'}, inplace=True)
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
keep_insurance['prescription_coverage'].value_counts(dropna=False)
# Out:
# yes          7678
# no_answer    1196
# no            379
# Name: prescription_coverage, dtype: int64

# %%
keep_insurance['uninsured_in_last_year'].value_counts(dropna=False)
# Out:
# 2.0    7591
# NaN    1082
# 1.0     561
# 9.0      18
# 7.0       1
# Name: uninsured_in_last_year, dtype: int64

# %%
keep_insurance['uninsured_in_last_year'].replace({1.0: 'yes',
                                          2.0: 'no',
                                          7.0: 'no_answer',
                                          9.0: 'no_answer'}, inplace=True)

# %%
keep_insurance[keep_insurance['uninsured_in_last_year'].isna()]
# Out:
#        coverage_status  ... uninsured_in_last_year
# SEQN                    ...
# 93712        uninsured  ...                    NaN
# 93717        uninsured  ...                    NaN
# 93729        no_answer  ...                    NaN
# 93730        uninsured  ...                    NaN
# 93743        uninsured  ...                    NaN
# ...                ...  ...                    ...
# 102884       uninsured  ...                    NaN
# 102898       uninsured  ...                    NaN
# 102918       uninsured  ...                    NaN
# 102921       uninsured  ...                    NaN
# 102922       uninsured  ...                    NaN
#
# [1082 rows x 12 columns]

# %%
# determined that respondents who indicated their "coverage status" is currently uninsured 
# have been uninsured in the last 12 months

for ind, row in keep_insurance.iterrows():
    if keep_insurance['coverage_status'][ind] == 'uninsured':
        keep_insurance['uninsured_in_last_year'][ind] = 'yes'
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3417: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
keep_insurance[keep_insurance['uninsured_in_last_year'].isna()]
# Out:
#        coverage_status  ... uninsured_in_last_year
# SEQN                    ...
# 93729        no_answer  ...                    NaN
# 93902        no_answer  ...                    NaN
# 93981        no_answer  ...                    NaN
# 95301        no_answer  ...                    NaN
# 95515        no_answer  ...                    NaN
# 95567        no_answer  ...                    NaN
# 95659        no_answer  ...                    NaN
# 96934        no_answer  ...                    NaN
# 97033        no_answer  ...                    NaN
# 97306        no_answer  ...                    NaN
# 97486        no_answer  ...                    NaN
# 97531        no_answer  ...                    NaN
# 97774        no_answer  ...                    NaN
# 98146        no_answer  ...                    NaN
# 98618        no_answer  ...                    NaN
# 98628        no_answer  ...                    NaN
# 98926        no_answer  ...                    NaN
# 98962        no_answer  ...                    NaN
# 99065        no_answer  ...                    NaN
# 99576        no_answer  ...                    NaN
# 100464       no_answer  ...                    NaN
# 100601       no_answer  ...                    NaN
# 100950       no_answer  ...                    NaN
# 100981       no_answer  ...                    NaN
# 101975       no_answer  ...                    NaN
#
# [25 rows x 12 columns]

# %%
keep_insurance['uninsured_in_last_year'].fillna('no_answer', inplace=True)
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
keep_insurance['uninsured_in_last_year'].value_counts(dropna=False)
# Out:
# no           7578
# yes          1631
# no_answer      44
# Name: uninsured_in_last_year, dtype: int64

# %%
keep_insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9253 entries, 93703 to 102956
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   coverage_status         9253 non-null   object
#  1   covered_private         9253 non-null   object
#  2   covered_medicare        9253 non-null   object
#  3   covered_medigap         9253 non-null   object
#  4   covered_medicaid        9253 non-null   object
#  5   covered_chip            9253 non-null   object
#  6   covered_military        9253 non-null   object
#  7   covered_state           9253 non-null   object
#  8   covered_other_gov       9253 non-null   object
#  9   covered_single_service  9253 non-null   object
#  10  prescription_coverage   9253 non-null   object
#  11  uninsured_in_last_year  9253 non-null   object
# dtypes: object(12)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Body Measures
#
# [View source for additional description and details](https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/BMX_J.htm)
#
# Body measures including height, weight, waist and hip circumference were taken for adult participants. Body Mass Index (BMI) was calculated as weight in kilograms divided by height in meters squared, and then rounded to one decimal place.

# %%
measures
# Out:
#         BMDSTATS  BMXWT  BMIWT  BMXRECUM  ...  BMXWAIST  BMIWAIST  BMXHIP  BMIHIP
# SEQN                                      ...
# 93703        1.0   13.7    3.0      89.6  ...      48.2       NaN     NaN     NaN
# 93704        1.0   13.9    NaN      95.0  ...      50.0       NaN     NaN     NaN
# 93705        1.0   79.5    NaN       NaN  ...     101.8       NaN   110.0     NaN
# 93706        1.0   66.3    NaN       NaN  ...      79.3       NaN    94.4     NaN
# 93707        1.0   45.4    NaN       NaN  ...      64.1       NaN    83.0     NaN
# ...          ...    ...    ...       ...  ...       ...       ...     ...     ...
# 102952       1.0   49.0    NaN       NaN  ...      82.2       NaN    87.3     NaN
# 102953       1.0   97.4    NaN       NaN  ...     114.8       NaN   112.8     NaN
# 102954       1.0   69.1    NaN       NaN  ...      86.4       NaN   102.7     NaN
# 102955       1.0  111.9    NaN       NaN  ...     113.5       NaN   128.3     NaN
# 102956       1.0  111.5    NaN       NaN  ...     122.0       NaN   110.0     NaN
#
# [8704 rows x 20 columns]

# %%
measures.columns
# Out:
# Index(['BMDSTATS', 'BMXWT', 'BMIWT', 'BMXRECUM', 'BMIRECUM', 'BMXHEAD',
#        'BMIHEAD', 'BMXHT', 'BMIHT', 'BMXBMI', 'BMXLEG', 'BMILEG', 'BMXARML',
#        'BMIARML', 'BMXARMC', 'BMIARMC', 'BMXWAIST', 'BMIWAIST', 'BMXHIP',
#        'BMIHIP'],
#       dtype='object')

# %%
keepcols_measures = ['BMXWT', 'BMXHT', 'BMXBMI', 'BMXWAIST', 'BMXHIP']

# %%
keep_measures = measures.copy()[keepcols_measures]
keep_measures.rename(mapper={'BMXWT': 'weight_kg', 
                             'BMXHT': 'height_cm',
                             'BMXBMI': 'BMI',
                             'BMXWAIST': 'waist_circumference_cm',
                             'BMXHIP': 'hip_circumference_cm'},
                    axis=1, inplace=True)
keep_measures
# Out:
#         weight_kg  height_cm  ...  waist_circumference_cm  hip_circumference_cm
# SEQN                          ...
# 93703        13.7       88.6  ...                    48.2                   NaN
# 93704        13.9       94.2  ...                    50.0                   NaN
# 93705        79.5      158.3  ...                   101.8                 110.0
# 93706        66.3      175.7  ...                    79.3                  94.4
# 93707        45.4      158.4  ...                    64.1                  83.0
# ...           ...        ...  ...                     ...                   ...
# 102952       49.0      156.5  ...                    82.2                  87.3
# 102953       97.4      164.9  ...                   114.8                 112.8
# 102954       69.1      162.6  ...                    86.4                 102.7
# 102955      111.9      156.6  ...                   113.5                 128.3
# 102956      111.5      175.8  ...                   122.0                 110.0
#
# [8704 rows x 5 columns]

# %%
keep_measures['weight_kg'].describe().round(1)
# Out:
# count    8580.0
# mean       65.1
# std        32.9
# min         3.2
# 25%        43.1
# 50%        67.8
# 75%        85.6
# max       242.6
# Name: weight_kg, dtype: float64

# %%
keep_measures['weight_kg'].isna().sum()
# Out:
# 124

# %%
keep_measures[keep_measures['weight_kg'].isna()]
# Out:
#         weight_kg  height_cm  BMI  waist_circumference_cm  hip_circumference_cm
# SEQN
# 93777         NaN        NaN  NaN                     NaN                   NaN
# 93816         NaN        NaN  NaN                     NaN                   NaN
# 93935         NaN        NaN  NaN                     NaN                   NaN
# 93955         NaN        NaN  NaN                     NaN                   NaN
# 94310         NaN        NaN  NaN                     NaN                   NaN
# ...           ...        ...  ...                     ...                   ...
# 102590        NaN        NaN  NaN                     NaN                   NaN
# 102610        NaN       96.2  NaN                     NaN                   NaN
# 102671        NaN        NaN  NaN                     NaN                   NaN
# 102684        NaN        NaN  NaN                     NaN                   NaN
# 102864        NaN        NaN  NaN                     NaN                   NaN
#
# [124 rows x 5 columns]

# %% [markdown]
# Because many of the 77 rows with missing weights are also missing heights and BMIs, they are removed from the dataset

# %%
keep_measures = keep_measures[~keep_measures['weight_kg'].isna()]
keep_measures
# Out:
#         weight_kg  height_cm  ...  waist_circumference_cm  hip_circumference_cm
# SEQN                          ...
# 93703        13.7       88.6  ...                    48.2                   NaN
# 93704        13.9       94.2  ...                    50.0                   NaN
# 93705        79.5      158.3  ...                   101.8                 110.0
# 93706        66.3      175.7  ...                    79.3                  94.4
# 93707        45.4      158.4  ...                    64.1                  83.0
# ...           ...        ...  ...                     ...                   ...
# 102952       49.0      156.5  ...                    82.2                  87.3
# 102953       97.4      164.9  ...                   114.8                 112.8
# 102954       69.1      162.6  ...                    86.4                 102.7
# 102955      111.9      156.6  ...                   113.5                 128.3
# 102956      111.5      175.8  ...                   122.0                 110.0
#
# [8580 rows x 5 columns]

# %%
keep_measures['weight_kg'].isna().sum()
# Out:
# 0

# %%
keep_measures['height_cm'].isna().sum()
# Out:
# 575

# %%
keep_measures[keep_measures['height_cm'].isna()]
# Out:
#         weight_kg  height_cm  BMI  waist_circumference_cm  hip_circumference_cm
# SEQN
# 93710        10.2        NaN  NaN                     NaN                   NaN
# 93720        10.6        NaN  NaN                     NaN                   NaN
# 93748         9.3        NaN  NaN                     NaN                   NaN
# 93749         8.3        NaN  NaN                     NaN                   NaN
# 93764         9.2        NaN  NaN                     NaN                   NaN
# ...           ...        ...  ...                     ...                   ...
# 102897       12.6        NaN  NaN                     NaN                   NaN
# 102919        7.2        NaN  NaN                     NaN                   NaN
# 102927        9.1        NaN  NaN                     NaN                   NaN
# 102936       10.2        NaN  NaN                     NaN                   NaN
# 102942        8.9        NaN  NaN                     NaN                   NaN
#
# [575 rows x 5 columns]

# %% [markdown]
# Because a these rows seem to be missing a lot of data, they are removed from the dataset.

# %%
keep_measures = keep_measures[~keep_measures['height_cm'].isna()]
keep_measures['height_cm'].isna().sum()
# Out:
# 0

# %%
keep_measures['BMI'].isna().sum()
# Out:
# 0

# %%
keep_measures['waist_circumference_cm'].isna().sum()
# Out:
# 419

# %%
keep_measures['hip_circumference_cm'].isna().sum()
# Out:
# 1975

# %% [markdown]
# Waist and hip circumference will be filled during the imputing step to come.

# %% [markdown]
# ### Physical Activity
#
# [View source for additional description and details](https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/PAQ_J.htm)
#
# Adult participants were surveyed on their general physical activity levels.

# %%
activity
# Out:
#         PAQ605  PAQ610  PAD615  PAQ620  ...  PAQ665  PAQ670  PAD675  PAD680
# SEQN                                    ...
# 93705      2.0     NaN     NaN     2.0  ...     1.0     2.0    60.0   300.0
# 93706      2.0     NaN     NaN     2.0  ...     1.0     2.0    30.0   240.0
# 93708      2.0     NaN     NaN     2.0  ...     1.0     5.0    30.0   120.0
# 93709      2.0     NaN     NaN     1.0  ...     2.0     NaN     NaN   600.0
# 93711      2.0     NaN     NaN     2.0  ...     1.0     2.0    30.0   420.0
# ...        ...     ...     ...     ...  ...     ...     ...     ...     ...
# 102950     2.0     NaN     NaN     2.0  ...     2.0     NaN     NaN    60.0
# 102952     2.0     NaN     NaN     2.0  ...     1.0     6.0    60.0   120.0
# 102953     1.0     3.0   240.0     1.0  ...     2.0     NaN     NaN   360.0
# 102954     2.0     NaN     NaN     2.0  ...     1.0     2.0    30.0   600.0
# 102956     2.0     NaN     NaN     2.0  ...     2.0     NaN     NaN   720.0
#
# [5856 rows x 16 columns]

# %%
activity.columns
# Out:
# Index(['PAQ605', 'PAQ610', 'PAD615', 'PAQ620', 'PAQ625', 'PAD630', 'PAQ635',
#        'PAQ640', 'PAD645', 'PAQ650', 'PAQ655', 'PAD660', 'PAQ665', 'PAQ670',
#        'PAD675', 'PAD680'],
#       dtype='object')

# %%
keepcols_activity = ['PAD615', 'PAQ610', 'PAD630', 'PAQ625', 'PAQ640', 'PAD645', 'PAD660', 
                     'PAQ655', 'PAD675', 'PAQ670', 'PAD680']
mapper_activity = {'PAD615':'work_vigorous_minperday', 
                   'PAQ610': 'work_vigorous_daysperweek',
                   'PAD630': 'work_moderate_minperday', 
                   'PAQ625': 'work_moderate_daysperweek',
                   'PAD645': 'transportation_minperday', 
                   'PAQ640': 'transportation_daysperweek',
                   'PAD660': 'recreation_vigorous_minperday', 
                   'PAQ655': 'recreation_vigorous_daysperweek',
                   'PAD675': 'recreation_moderate_minperday', 
                   'PAQ670': 'recreation_moderate_daysperweek',
                   'PAD680': 'sedentary_minsperday'}

# %%
keep_activity = activity.copy()[keepcols_activity].rename(mapper=mapper_activity, axis=1).fillna(0)
keep_activity
# Out:
#         work_vigorous_minperday  ...  sedentary_minsperday
# SEQN                             ...
# 93705                       0.0  ...                 300.0
# 93706                       0.0  ...                 240.0
# 93708                       0.0  ...                 120.0
# 93709                       0.0  ...                 600.0
# 93711                       0.0  ...                 420.0
# ...                         ...  ...                   ...
# 102950                      0.0  ...                  60.0
# 102952                      0.0  ...                 120.0
# 102953                    240.0  ...                 360.0
# 102954                      0.0  ...                 600.0
# 102956                      0.0  ...                 720.0
#
# [5856 rows x 11 columns]

# %%
days_cols = ['work_vigorous_daysperweek', 'work_moderate_daysperweek', 'transportation_daysperweek',
            'recreation_vigorous_daysperweek', 'recreation_moderate_daysperweek']
mins_cols = ['work_vigorous_minperday', 'work_moderate_minperday', 'transportation_minperday',
            'recreation_vigorous_minperday', 'recreation_moderate_minperday', ]

# %% [markdown]
# All the columns in units=days and all the columns in units=minutes have the same dummy values, so they are analyzed together. These are especially important to fix now in order to engineer a smaller number of features which summarize each respondent's vigorous, moderate, and sedentary activity levels.

# %%
for col in days_cols:
    print(col)
    display(keep_activity[col].value_counts())
    print('*****'*15)
# Out:
# work_vigorous_daysperweek
# 0.0     4467
# 5.0      384
# 3.0      232
# 2.0      178
# 6.0      160
# 4.0      153
# 7.0      151
# 1.0      130
# 99.0       1
# Name: work_vigorous_daysperweek, dtype: int64
# ***************************************************************************
# work_moderate_daysperweek
# 0.0     3417
# 5.0      702
# 3.0      401
# 7.0      331
# 2.0      308
# 4.0      307
# 6.0      210
# 1.0      174
# 99.0       6
# Name: work_moderate_daysperweek, dtype: int64
# ***************************************************************************
# transportation_daysperweek
# 0.0     4417
# 7.0      410
# 5.0      332
# 3.0      230
# 2.0      177
# 4.0      135
# 6.0       87
# 1.0       64
# 99.0       4
# Name: transportation_daysperweek, dtype: int64
# ***************************************************************************
# recreation_vigorous_daysperweek
# 0.0     4422
# 3.0      385
# 2.0      269
# 4.0      264
# 5.0      207
# 1.0      163
# 7.0       73
# 6.0       72
# 99.0       1
# Name: recreation_vigorous_daysperweek, dtype: int64
# ***************************************************************************
# recreation_moderate_daysperweek
# 0.0     3548
# 3.0      606
# 2.0      491
# 5.0      321
# 4.0      293
# 1.0      253
# 7.0      250
# 6.0       91
# 99.0       3
# Name: recreation_moderate_daysperweek, dtype: int64
# ***************************************************************************

# %%
for col in mins_cols:
    print(col)
    display(keep_activity[col].value_counts())
    print('*****'*15)
# Out:
# work_vigorous_minperday
# 0.0       4475
# 120.0      234
# 60.0       194
# 240.0      177
# 180.0      130
# 480.0      107
# 30.0       106
# 300.0       93
# 360.0       80
# 420.0       41
# 10.0        40
# 600.0       38
# 15.0        31
# 20.0        31
# 90.0        23
# 540.0       15
# 45.0        14
# 9999.0       6
# 150.0        4
# 40.0         4
# 720.0        4
# 25.0         2
# 80.0         1
# 12.0         1
# 840.0        1
# 35.0         1
# 780.0        1
# 140.0        1
# 660.0        1
# Name: work_vigorous_minperday, dtype: int64
# ***************************************************************************
# work_moderate_minperday
# 0.0       3430
# 120.0      449
# 60.0       362
# 240.0      317
# 180.0      277
# 30.0       206
# 300.0      150
# 480.0      131
# 360.0      125
# 10.0        76
# 20.0        75
# 15.0        55
# 90.0        39
# 420.0       38
# 600.0       34
# 45.0        28
# 540.0       14
# 9999.0      13
# 40.0        11
# 720.0        6
# 150.0        6
# 25.0         4
# 50.0         2
# 660.0        1
# 12.0         1
# 230.0        1
# 70.0         1
# 35.0         1
# 840.0        1
# 140.0        1
# 210.0        1
# Name: work_moderate_minperday, dtype: int64
# ***************************************************************************
# transportation_minperday
# 0.0       4426
# 30.0       333
# 60.0       270
# 20.0       176
# 10.0       154
# 15.0       119
# 120.0      118
# 40.0        45
# 180.0       38
# 45.0        36
# 240.0       30
# 90.0        28
# 25.0        21
# 300.0        8
# 480.0        8
# 360.0        6
# 420.0        6
# 50.0         5
# 80.0         4
# 9999.0       4
# 12.0         3
# 35.0         3
# 14.0         2
# 540.0        2
# 75.0         1
# 16.0         1
# 22.0         1
# 660.0        1
# 150.0        1
# 42.0         1
# 17.0         1
# 209.0        1
# 110.0        1
# 600.0        1
# 230.0        1
# Name: transportation_minperday, dtype: int64
# ***************************************************************************
# recreation_vigorous_minperday
# 0.0       4425
# 60.0       464
# 120.0      240
# 30.0       210
# 45.0       110
# 90.0       110
# 180.0       90
# 20.0        62
# 40.0        29
# 240.0       23
# 15.0        18
# 10.0        13
# 25.0        11
# 35.0        10
# 150.0       10
# 50.0         5
# 75.0         5
# 80.0         4
# 300.0        4
# 18.0         2
# 480.0        2
# 360.0        2
# 23.0         1
# 12.0         1
# 11.0         1
# 209.0        1
# 420.0        1
# 55.0         1
# 9999.0       1
# Name: recreation_vigorous_minperday, dtype: int64
# ***************************************************************************
# recreation_moderate_minperday
# 0.0       3555
# 60.0       641
# 30.0       557
# 120.0      260
# 20.0       194
# 45.0       123
# 15.0       102
# 90.0        80
# 180.0       77
# 10.0        73
# 40.0        59
# 240.0       54
# 300.0       16
# 25.0        16
# 35.0         8
# 50.0         7
# 360.0        6
# 80.0         4
# 75.0         4
# 480.0        4
# 12.0         3
# 22.0         2
# 420.0        2
# 150.0        2
# 540.0        1
# 55.0         1
# 16.0         1
# 28.0         1
# 100.0        1
# 210.0        1
# 9999.0       1
# Name: recreation_moderate_minperday, dtype: int64
# ***************************************************************************

# %%
for col in days_cols:
    keep_activity[col].replace({77.0: 0, 99.0:0}, inplace=True)
for col in mins_cols:
    keep_activity[col].replace({7777.0: 0, 9999.0: 0}, inplace=True)

# %%
for col in days_cols:
    print(col)
    display(keep_activity[col].value_counts())
    print('_____'*20)
# Out:
# work_vigorous_daysperweek
# 0.0    4468
# 5.0     384
# 3.0     232
# 2.0     178
# 6.0     160
# 4.0     153
# 7.0     151
# 1.0     130
# Name: work_vigorous_daysperweek, dtype: int64
# ____________________________________________________________________________________________________
# work_moderate_daysperweek
# 0.0    3423
# 5.0     702
# 3.0     401
# 7.0     331
# 2.0     308
# 4.0     307
# 6.0     210
# 1.0     174
# Name: work_moderate_daysperweek, dtype: int64
# ____________________________________________________________________________________________________
# transportation_daysperweek
# 0.0    4421
# 7.0     410
# 5.0     332
# 3.0     230
# 2.0     177
# 4.0     135
# 6.0      87
# 1.0      64
# Name: transportation_daysperweek, dtype: int64
# ____________________________________________________________________________________________________
# recreation_vigorous_daysperweek
# 0.0    4423
# 3.0     385
# 2.0     269
# 4.0     264
# 5.0     207
# 1.0     163
# 7.0      73
# 6.0      72
# Name: recreation_vigorous_daysperweek, dtype: int64
# ____________________________________________________________________________________________________
# recreation_moderate_daysperweek
# 0.0    3551
# 3.0     606
# 2.0     491
# 5.0     321
# 4.0     293
# 1.0     253
# 7.0     250
# 6.0      91
# Name: recreation_moderate_daysperweek, dtype: int64
# ____________________________________________________________________________________________________

# %%
for col in mins_cols:
    print(col)
    display(keep_activity[col].value_counts())
    print('_____'*20)
# Out:
# work_vigorous_minperday
# 0.0      4481
# 120.0     234
# 60.0      194
# 240.0     177
# 180.0     130
# 480.0     107
# 30.0      106
# 300.0      93
# 360.0      80
# 420.0      41
# 10.0       40
# 600.0      38
# 20.0       31
# 15.0       31
# 90.0       23
# 540.0      15
# 45.0       14
# 150.0       4
# 40.0        4
# 720.0       4
# 25.0        2
# 80.0        1
# 12.0        1
# 840.0       1
# 35.0        1
# 780.0       1
# 140.0       1
# 660.0       1
# Name: work_vigorous_minperday, dtype: int64
# ____________________________________________________________________________________________________
# work_moderate_minperday
# 0.0      3443
# 120.0     449
# 60.0      362
# 240.0     317
# 180.0     277
# 30.0      206
# 300.0     150
# 480.0     131
# 360.0     125
# 10.0       76
# 20.0       75
# 15.0       55
# 90.0       39
# 420.0      38
# 600.0      34
# 45.0       28
# 540.0      14
# 40.0       11
# 150.0       6
# 720.0       6
# 25.0        4
# 50.0        2
# 660.0       1
# 12.0        1
# 230.0       1
# 70.0        1
# 35.0        1
# 840.0       1
# 140.0       1
# 210.0       1
# Name: work_moderate_minperday, dtype: int64
# ____________________________________________________________________________________________________
# transportation_minperday
# 0.0      4430
# 30.0      333
# 60.0      270
# 20.0      176
# 10.0      154
# 15.0      119
# 120.0     118
# 40.0       45
# 180.0      38
# 45.0       36
# 240.0      30
# 90.0       28
# 25.0       21
# 300.0       8
# 480.0       8
# 360.0       6
# 420.0       6
# 50.0        5
# 80.0        4
# 35.0        3
# 12.0        3
# 540.0       2
# 14.0        2
# 75.0        1
# 16.0        1
# 22.0        1
# 660.0       1
# 150.0       1
# 42.0        1
# 17.0        1
# 209.0       1
# 110.0       1
# 600.0       1
# 230.0       1
# Name: transportation_minperday, dtype: int64
# ____________________________________________________________________________________________________
# recreation_vigorous_minperday
# 0.0      4426
# 60.0      464
# 120.0     240
# 30.0      210
# 45.0      110
# 90.0      110
# 180.0      90
# 20.0       62
# 40.0       29
# 240.0      23
# 15.0       18
# 10.0       13
# 25.0       11
# 150.0      10
# 35.0       10
# 50.0        5
# 75.0        5
# 80.0        4
# 300.0       4
# 18.0        2
# 480.0       2
# 360.0       2
# 209.0       1
# 12.0        1
# 420.0       1
# 23.0        1
# 55.0        1
# 11.0        1
# Name: recreation_vigorous_minperday, dtype: int64
# ____________________________________________________________________________________________________
# recreation_moderate_minperday
# 0.0      3556
# 60.0      641
# 30.0      557
# 120.0     260
# 20.0      194
# 45.0      123
# 15.0      102
# 90.0       80
# 180.0      77
# 10.0       73
# 40.0       59
# 240.0      54
# 300.0      16
# 25.0       16
# 35.0        8
# 50.0        7
# 360.0       6
# 80.0        4
# 75.0        4
# 480.0       4
# 12.0        3
# 420.0       2
# 150.0       2
# 22.0        2
# 540.0       1
# 55.0        1
# 16.0        1
# 28.0        1
# 100.0       1
# 210.0       1
# Name: recreation_moderate_minperday, dtype: int64
# ____________________________________________________________________________________________________

# %% [markdown]
# Three features were engineered to summarize activity levels by multiplying days per week times minutes per day of each activity type, then adding work and recreation activity together.

# %%
keep_activity['vigorous_activity_minsperweek'] =\
            (keep_activity['work_vigorous_daysperweek']*keep_activity['work_vigorous_minperday']) +\
            (keep_activity['recreation_vigorous_daysperweek']*keep_activity['recreation_vigorous_daysperweek'])

keep_activity['moderate_activity_minsperweek'] =\
            (keep_activity['work_moderate_daysperweek']*keep_activity['work_moderate_minperday']) +\
            (keep_activity['recreation_moderate_daysperweek']*keep_activity['recreation_moderate_minperday']) +\
            (keep_activity['transportation_daysperweek']*keep_activity['transportation_minperday'])

keep_activity
# Out:
#         work_vigorous_minperday  ...  moderate_activity_minsperweek
# SEQN                             ...
# 93705                       0.0  ...                          120.0
# 93706                       0.0  ...                          285.0
# 93708                       0.0  ...                          150.0
# 93709                       0.0  ...                          360.0
# 93711                       0.0  ...                          360.0
# ...                         ...  ...                            ...
# 102950                      0.0  ...                            0.0
# 102952                      0.0  ...                          360.0
# 102953                    240.0  ...                          720.0
# 102954                      0.0  ...                           60.0
# 102956                      0.0  ...                            0.0
#
# [5856 rows x 13 columns]

# %%
keep_activity2 = keep_activity[['sedentary_minsperday',
                                'vigorous_activity_minsperweek',
                                'moderate_activity_minsperweek']]
keep_activity2
# Out:
#         sedentary_minsperday  ...  moderate_activity_minsperweek
# SEQN                          ...
# 93705                  300.0  ...                          120.0
# 93706                  240.0  ...                          285.0
# 93708                  120.0  ...                          150.0
# 93709                  600.0  ...                          360.0
# 93711                  420.0  ...                          360.0
# ...                      ...  ...                            ...
# 102950                  60.0  ...                            0.0
# 102952                 120.0  ...                          360.0
# 102953                 360.0  ...                          720.0
# 102954                 600.0  ...                           60.0
# 102956                 720.0  ...                            0.0
#
# [5856 rows x 3 columns]

# %%
keep_activity2.describe().round(2)
# Out:
#        sedentary_minsperday  ...  moderate_activity_minsperweek
# count               5856.00  ...                        5856.00
# mean                 388.89  ...                         491.14
# std                  771.32  ...                         777.00
# min                    0.00  ...                           0.00
# 25%                  180.00  ...                           0.00
# 50%                  300.00  ...                         150.00
# 75%                  480.00  ...                         600.00
# max                 9999.00  ...                        5880.00
#
# [8 rows x 3 columns]

# %% [markdown]
# ### Blood Pressure

# %% [markdown]
# [View source for additional description and details](https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/BPXO_J.htm)
#
# Pulse is captured in the blood pressure data file. Because this model seeks to predict diabetes based only on easily-accessible questionnaire data or body measurements, pulse is the only measurement used from this file. For the purposes of this analysis, an average of three oscillometric measurements was calculated.

# %%
bp
# Out:
#        BPAOARM  BPAOCSZ  BPAOMNTS  ...  BPXOPLS1  BPXOPLS2  BPXOPLS3
# SEQN                               ...
# 93705     b'R'      4.0     -20.0  ...      52.0      51.0      49.0
# 93706     b'R'      3.0     138.0  ...      76.0      83.0      73.0
# 93707     b'R'      2.0      12.0  ...     100.0      89.0      91.0
# 93708     b'R'      3.0      22.0  ...      67.0      65.0      71.0
# 93709     b'R'      4.0      58.0  ...      64.0      62.0      61.0
# ...        ...      ...       ...  ...       ...       ...       ...
# 102952    b'R'      3.0      97.0  ...      88.0      84.0      74.0
# 102953    b'R'      4.0     -57.0  ...      76.0      79.0      78.0
# 102954     b''      3.0    -101.0  ...       NaN       NaN       NaN
# 102955    b'R'      5.0     -88.0  ...      71.0      71.0      76.0
# 102956    b'R'      4.0      30.0  ...      72.0      74.0      75.0
#
# [7132 rows x 12 columns]

# %%
bp.columns
# Out:
# Index(['BPAOARM', 'BPAOCSZ', 'BPAOMNTS', 'BPXOSY1', 'BPXODI1', 'BPXOSY2',
#        'BPXODI2', 'BPXOSY3', 'BPXODI3', 'BPXOPLS1', 'BPXOPLS2', 'BPXOPLS3'],
#       dtype='object')

# %%
keepcols_bp = ['BPXOPLS1', 'BPXOPLS2', 'BPXOPLS3']
mapper_bp = {'BPXOPLS1': 'pulse_1', 'BPXOPLS2': 'pulse_2', 'BPXOPLS3': 'pulse_3'}

# %%
pulse = bp[keepcols_bp]
pulse.rename(mapper=mapper_bp, axis=1, inplace=True)
pulse
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#         pulse_1  pulse_2  pulse_3
# SEQN
# 93705      52.0     51.0     49.0
# 93706      76.0     83.0     73.0
# 93707     100.0     89.0     91.0
# 93708      67.0     65.0     71.0
# 93709      64.0     62.0     61.0
# ...         ...      ...      ...
# 102952     88.0     84.0     74.0
# 102953     76.0     79.0     78.0
# 102954      NaN      NaN      NaN
# 102955     71.0     71.0     76.0
# 102956     72.0     74.0     75.0
#
# [7132 rows x 3 columns]

# %%
pulse['avg_pulse'] = ((pulse['pulse_1'] + pulse['pulse_2'] + pulse['pulse_3']) / 3).round(1)
pulse = pd.DataFrame(pulse['avg_pulse'])
pulse
# Out:
# <ipython-input-119-5c63e71f4110>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pulse['avg_pulse'] = ((pulse['pulse_1'] + pulse['pulse_2'] + pulse['pulse_3']) / 3).round(1)
#         avg_pulse
# SEQN
# 93705        50.7
# 93706        77.3
# 93707        93.3
# 93708        67.7
# 93709        62.3
# ...           ...
# 102952       82.0
# 102953       77.7
# 102954        NaN
# 102955       72.7
# 102956       73.7
#
# [7132 rows x 1 columns]

# %% [markdown]
# ### Nicotine Usage
#
# [View source for additional description and details](https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/SMQ_J.htm#Component_Description)
#
# The Smoking - Cigarette Use dataset provides a history of cigarette use, age at initiation, past 30-day use, cigarette brand, sub-brand and other related details. Questions on ever use of cigars, smokeless tobacco, and electronic nicotine delivery systems (including e-cigarettes) were added to NHANES in 2015-16.
#
# Based on the source data available and domain knowledge, four nicotine usage features were defined as:
# - **Lifetime cigarette smoker** - respondent has smoked at least 100 cigarettes in their lifetime
# - **Current cigarette smoker** - respondent currently smokes every day or some days
# - **E-cigarette smoker** - respondent has smoked an ecigarette at least once in the last 30 days
# - **Smokeless tobacco user** - respondent has used smokeless tobacco at least once in the last 30 days
#
#
# Because there are no obvious assumptions with which to fill null values, they will be addressed at the imputing step.

# %%
smoking.head()
# Out:
#        SMQ020  SMD030  SMQ040  ...  SMQ910        SMQ915  SMAQUEX2
# SEQN                           ...
# 93705     1.0    16.0     3.0  ...     2.0           NaN       1.0
# 93706     2.0     NaN     NaN  ...     2.0           NaN       1.0
# 93707     NaN     NaN     NaN  ...     NaN           NaN       2.0
# 93708     2.0     NaN     NaN  ...     2.0           NaN       1.0
# 93709     1.0    15.0     1.0  ...     1.0  5.397605e-79       1.0
#
# [5 rows x 36 columns]

# %%
keepcols_smoking = ['SMQ020', 'SMQ040', 'SMQ905', 'SMQ915']
mapper_smoking = {'SMQ020': 'lifetime_cigarette_smoker', 
                 'SMQ040': 'current_cigarette_smoker',
                 'SMQ905': 'ecig_smoker',
                 'SMQ915': 'smokeless_tobacco_user'}

# %%
keep_smoking = smoking[keepcols_smoking].rename(mapper=mapper_smoking, axis=1)
keep_smoking.round(1)
# Out:
#         lifetime_cigarette_smoker  ...  smokeless_tobacco_user
# SEQN                               ...
# 93705                         1.0  ...                     NaN
# 93706                         2.0  ...                     NaN
# 93707                         NaN  ...                     NaN
# 93708                         2.0  ...                     NaN
# 93709                         1.0  ...                     0.0
# ...                           ...  ...                     ...
# 102952                        2.0  ...                     NaN
# 102953                        1.0  ...                     0.0
# 102954                        2.0  ...                     NaN
# 102955                        NaN  ...                     NaN
# 102956                        1.0  ...                     0.0
#
# [6724 rows x 4 columns]

# %%
keep_smoking['lifetime_cigarette_smoker'].value_counts(dropna=False)
# Out:
# 2.0    3497
# 1.0    2359
# NaN     868
# Name: lifetime_cigarette_smoker, dtype: int64

# %%
keep_smoking['lifetime_cigarette_smoker'].replace({1.0: 'yes', 2.0: 'no'}, inplace=True)

# %%
keep_smoking['current_cigarette_smoker'].value_counts(dropna=False)
# Out:
# NaN    4365
# 3.0    1338
# 1.0     805
# 2.0     216
# Name: current_cigarette_smoker, dtype: int64

# %%
keep_smoking['current_cigarette_smoker'].replace({1.0: 'yes',
                                            2.0: 'yes',
                                            3.0: 'no'}, inplace=True)

# %%
keep_smoking['current_cigarette_smoker'].value_counts(dropna=False)
# Out:
# NaN    4365
# no     1338
# yes    1021
# Name: current_cigarette_smoker, dtype: int64

# %%
keep_smoking['ecig_smoker'].value_counts(dropna=False)
# Out:
# NaN             5574
# 5.397605e-79     844
# 1.000000e+00     102
# 3.000000e+01      55
# 2.000000e+00      43
# 3.000000e+00      21
# 5.000000e+00      20
# 1.500000e+01      19
# 1.000000e+01      11
# 4.000000e+00      10
# 2.000000e+01       7
# 2.100000e+01       3
# 7.000000e+00       3
# 9.000000e+00       3
# 1.200000e+01       2
# 6.000000e+00       2
# 2.500000e+01       2
# 2.800000e+01       1
# 1.400000e+01       1
# 9.900000e+01       1
# Name: ecig_smoker, dtype: int64

# %%
for ind, row in keep_smoking.iterrows():
    if keep_smoking['ecig_smoker'][ind] > 0:
        keep_smoking['ecig_smoker'][ind] = 'yes'
# Out:
# <ipython-input-129-0391f3294e35>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keep_smoking['ecig_smoker'][ind] = 'yes'
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
keep_smoking['smokeless_tobacco_user'].value_counts(dropna=False)
# Out:
# NaN             5863
# 5.397605e-79     720
# 3.000000e+01      71
# 1.000000e+00      22
# 2.000000e+00      17
# 4.000000e+00       6
# 5.000000e+00       4
# 3.000000e+00       4
# 2.000000e+01       4
# 1.000000e+01       4
# 1.500000e+01       3
# 7.000000e+00       2
# 2.500000e+01       1
# 1.200000e+01       1
# 9.000000e+00       1
# 2.800000e+01       1
# Name: smokeless_tobacco_user, dtype: int64

# %%
for ind, row in keep_smoking.iterrows():
    if keep_smoking['smokeless_tobacco_user'][ind] > 0:
        keep_smoking['smokeless_tobacco_user'][ind] = 'yes'
# Out:
# <ipython-input-131-d865f51e87fd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keep_smoking['smokeless_tobacco_user'][ind] = 'yes'

# %% [markdown]
# ### A1C
#
# [View source for additional description and details](https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/GHB_J.htm)
#
# Per [the Mayo Clinic](https://www.mayoclinic.org/diseases-conditions/diabetes/diagnosis-treatment/drc-20371451#:~:text=A%20fasting%20blood%20sugar%20level,separate%20tests%2C%20you%20have%20diabetes.), the Glycated Hemoglobin (A1C) test indicates a person's average blood sugar level for the past two to three months. It measures the percentage of blood sugar attached to hemoglobin, the oxygen-carrying protein in red blood cells. The higher your blood sugar levels, the more hemoglobin you'll have with sugar attached.
#
# * A1C level of 6.5% or higher on two separate tests indicates that you have diabetes
# * A1C between 5.7 and 6.4 % indicates prediabetes
# * A1C below 5.7 is considered normal
#
# NHANES examined participants age 12+ provided a blood sample for analysis.

# %%
a1c
# Out:
#         LBXGH
# SEQN
# 93705     6.2
# 93706     5.2
# 93707     5.6
# 93708     6.2
# 93709     6.3
# ...       ...
# 102952    7.4
# 102953    5.9
# 102954    5.2
# 102955    5.5
# 102956    5.4
#
# [6401 rows x 1 columns]

# %%
a1c.rename(mapper={'LBXGH': 'glycohemoglobin'}, axis=1, inplace=True)

# %%
a1c.isna().sum()
# Out:
# glycohemoglobin    356
# dtype: int64

# %% [markdown]
# Because this is our target in a supervised learning task, all nulls were removed.

# %%
a1c.dropna(inplace=True)

# %% [markdown]
# One approach is to create binary classes for normal vs elevated A1C levels. The multi-variate approach would require the model to predict one of three classes: normal, prediabetic, or diabetic.
#
# For the initial model, we'll work with binary classes, though a multiclass model may also be of interest in the future.
#
# Special care is taken when encoding the diagnosis values to help the model's interpretability - 0=normal, 1=diabetic/prediabetic

# %%
def diagnose_multiclass(a1c_value):
    diagnosis = None
    if a1c_value >= 6.5:
        diagnosis = 'Diabetic'
    if (a1c_value >= 5.7) & (a1c_value < 6.5):
        diagnosis = 'Prediabetic'
    if a1c_value < 5.7:
        diagnosis = 'Normal'
    return diagnosis

def diagnose_binary(a1c_value):
    '''
    Returns binary values; 0 indicates normal, 1 indicates diabetic/prediabetic
    '''
    diagnosis = None
    if (a1c_value >= 5.7):
        diagnosis = 1
    if a1c_value < 5.7:
        diagnosis = 0
    return diagnosis

# %%
a1c['diagnosis'] = a1c.glycohemoglobin.map(lambda x: diagnose_binary(x))
a1c
# Out:
#         glycohemoglobin  diagnosis
# SEQN
# 93705               6.2          1
# 93706               5.2          0
# 93707               5.6          0
# 93708               6.2          1
# 93709               6.3          1
# ...                 ...        ...
# 102952              7.4          1
# 102953              5.9          1
# 102954              5.2          0
# 102955              5.5          0
# 102956              5.4          0
#
# [6045 rows x 2 columns]

# %%
display(a1c.diagnosis.value_counts())
display(a1c.diagnosis.value_counts(normalize=True).round(2))
# Out:
# 0    3659
# 1    2386
# Name: diagnosis, dtype: int64
# 0    0.61
# 1    0.39
# Name: diagnosis, dtype: float64

# %% [markdown]
# # Merging and Preprocessing Data
#
#
# Once all data files are loaded and initial processing complete, some additional steps are needed before the sample can be modeled.
#
# The preprocessing workflow:
# 1. **Merge data files into one dataframe,** ensuring all samples in the final set have valid/unimputed A1C / diagnosis values. Body measures were determined to be the second-most critical data to the model since prior research shows that weight/BMI is a key risk factor for diabetes. Appropriate steps are taken at the merging step to ensure the final combined dataset has as many natural/unimputed body measures as possible without too much data leakage.
# 1. **Encode categorical features** with number values (0=False, 1=True) so model algorithms can interpret the data.
# 1. Split the dataset into **training and testing samples.** Models will be fit to the training sample, then validated against the testing sample.
#     - It is important that this step occurs before any processing that uses the sample data as a whole to define other values (ex. some feature engineering, null value imputation, normalization, etc.), since the testing data should imitate real-world new/novel data as closely as possible to evaluate how good the model actually is.
# 1. **Fill remaining null values** using a model that guesses the missing value based on the rest of the dataset.
# 1. **50/50 balance the number of diabetic and nondiabetic respondents represented in the training data**, so the model doesn't accidentally perform well just based on the laws of probability.
# 1. **Standard-scale** the continuous data in order to compare feature importances.

# %% [markdown]
# ## Merge

# %%
# Concatenated all but two most important dfs - a1c (target) and measures (includes height, weight, etc.)

concat = pd.concat([keep_demographic, keep_insurance, keep_activity2, pulse, keep_smoking],
                   join='outer', axis=1)
concat
# Out:
#         gender   age  ... ecig_smoker smokeless_tobacco_user
# SEQN                  ...
# 93703      NaN   NaN  ...         NaN                    NaN
# 93704      NaN   NaN  ...         NaN                    NaN
# 93705   female  66.0  ...         NaN                    NaN
# 93706     male  18.0  ...         NaN                    NaN
# 93707      NaN   NaN  ...         NaN                    NaN
# ...        ...   ...  ...         ...                    ...
# 102952  female  70.0  ...         NaN                    NaN
# 102953    male  42.0  ...         yes                    yes
# 102954  female  41.0  ...         NaN                    NaN
# 102955     NaN   NaN  ...         NaN                    NaN
# 102956    male  38.0  ...         NaN                    yes
#
# [9254 rows x 31 columns]

# %%
# inner merge on 2 most important dfs in order to only keep IDs where both data exists
inner_merge = pd.merge(a1c, keep_measures, how='inner', on='SEQN')
display(inner_merge.head())
inner_merge.index.value_counts().sum()
# Out:
#        glycohemoglobin  diagnosis  ...  waist_circumference_cm  hip_circumference_cm
# SEQN                               ...
# 93705              6.2          1  ...                   101.8                 110.0
# 93706              5.2          0  ...                    79.3                  94.4
# 93707              5.6          0  ...                    64.1                  83.0
# 93708              6.2          1  ...                    88.2                  90.1
# 93709              6.3          1  ...                   113.0                 131.3
#
# [5 rows x 7 columns]
# 5951

# %%
# left merge the concatenated df onto the merged a1c and body measures df
mega_df = pd.merge(inner_merge, concat, how='left', on='SEQN')

# drop the lab results
mega_df.drop(columns='glycohemoglobin', inplace=True)

# %%
display(mega_df.head())
display(mega_df.info())
# Out:
#        diagnosis  weight_kg  ...  ecig_smoker  smokeless_tobacco_user
# SEQN                         ...
# 93705          1       79.5  ...          NaN                     NaN
# 93706          0       66.3  ...          NaN                     NaN
# 93707          0       45.4  ...          NaN                     NaN
# 93708          1       53.5  ...          NaN                     NaN
# 93709          1       88.8  ...          yes                     yes
#
# [5 rows x 37 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5951 entries, 93705 to 102956
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   diagnosis                      5951 non-null   int64
#  1   weight_kg                      5951 non-null   float64
#  2   height_cm                      5951 non-null   float64
#  3   BMI                            5951 non-null   float64
#  4   waist_circumference_cm         5738 non-null   float64
#  5   hip_circumference_cm           5751 non-null   float64
#  6   gender                         5128 non-null   object
#  7   age                            5128 non-null   float64
#  8   race                           5128 non-null   object
#  9   veteran_status                 5128 non-null   object
#  10  country_of_birth               5128 non-null   object
#  11  citizen_status                 5128 non-null   object
#  12  education                      4884 non-null   object
#  13  marital_status                 5128 non-null   object
#  14  household_size                 5128 non-null   float64
#  15  annual_household_income        4655 non-null   float64
#  16  income_poverty_ratio           4466 non-null   float64
#  17  coverage_status                5950 non-null   object
#  18  covered_private                5950 non-null   object
#  19  covered_medicare               5950 non-null   object
#  20  covered_medigap                5950 non-null   object
#  21  covered_medicaid               5950 non-null   object
#  22  covered_chip                   5950 non-null   object
#  23  covered_military               5950 non-null   object
#  24  covered_state                  5950 non-null   object
#  25  covered_other_gov              5950 non-null   object
#  26  covered_single_service         5950 non-null   object
#  27  prescription_coverage          5950 non-null   object
#  28  uninsured_in_last_year         5950 non-null   object
#  29  sedentary_minsperday           5175 non-null   float64
#  30  vigorous_activity_minsperweek  5175 non-null   float64
#  31  moderate_activity_minsperweek  5175 non-null   float64
#  32  avg_pulse                      4500 non-null   float64
#  33  lifetime_cigarette_smoker      5175 non-null   object
#  34  current_cigarette_smoker       2100 non-null   object
#  35  ecig_smoker                    1027 non-null   object
#  36  smokeless_tobacco_user         762 non-null    object
# dtypes: float64(13), int64(1), object(23)
# memory usage: 1.7+ MB
# None

# %% [markdown]
# ## One-Hot Encode

# %%
mega_df_encoded = pd.get_dummies(mega_df, drop_first=True, dtype='float')
mega_df_encoded.head()
# Out:
#        diagnosis  ...  current_cigarette_smoker_yes
# SEQN              ...
# 93705          1  ...                           0.0
# 93706          0  ...                           0.0
# 93707          0  ...                           0.0
# 93708          1  ...                           0.0
# 93709          1  ...                           1.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
# use the same random state on every step that involves a random sampling
rs = 610
y = mega_df_encoded['diagnosis']
X = mega_df_encoded.drop(columns='diagnosis')
X_train , X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=rs)

# %%
print(f'X Train Shape: {X_train.shape}\nX Test Shape: {X_test.shape}')

display(X_train.head())
display(y_train.head())
# Out:
# X Train Shape: (4760, 47)
# X Test Shape: (1191, 47)
#         weight_kg  ...  current_cigarette_smoker_yes
# SEQN               ...
# 102783       64.8  ...                           0.0
# 99996        84.6  ...                           1.0
# 99721        74.8  ...                           0.0
# 97169        87.9  ...                           0.0
# 94465       106.2  ...                           0.0
#
# [5 rows x 47 columns]
# SEQN
# 102783    1
# 99996     1
# 99721     0
# 97169     1
# 94465     0
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## Impute Remaining Null Values
#
# Scikit-learn's experimental IterativeImputer class models each feature with null values as a function of other features to intelligently fill missing values. This is an experimental class, but performed better than the KNNImputer. This class may change; please review the documentation [here.](https://scikit-learn.org/stable/modules/generated/sklearn.impute.KNNImputer.html)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
X_train.isna().sum()
# Out:
# weight_kg                                           0
# height_cm                                           0
# BMI                                                 0
# waist_circumference_cm                            180
# hip_circumference_cm                              170
# age                                               660
# household_size                                    660
# annual_household_income                          1039
# income_poverty_ratio                             1185
# sedentary_minsperday                              622
# vigorous_activity_minsperweek                     622
# moderate_activity_minsperweek                     622
# avg_pulse                                        1153
# gender_male                                         0
# race_black                                          0
# race_hispanic                                       0
# race_mexican_american                               0
# race_other                                          0
# race_white                                          0
# veteran_status_yes                                  0
# country_of_birth_usa                                0
# citizen_status_no_answer                            0
# citizen_status_non_citizen                          0
# education_highschool_grad                           0
# education_no_diploma                                0
# education_some_college                              0
# marital_status_married or living with partner       0
# marital_status_never married                        0
# marital_status_no_answer                            0
# marital_status_widowed                              0
# coverage_status_no_answer                           0
# coverage_status_uninsured                           0
# covered_private_yes                                 0
# covered_medicare_yes                                0
# covered_medigap_yes                                 0
# covered_medicaid_yes                                0
# covered_chip_yes                                    0
# covered_military_yes                                0
# covered_state_yes                                   0
# covered_other_gov_yes                               0
# covered_single_service_yes                          0
# prescription_coverage_no_answer                     0
# prescription_coverage_yes                           0
# uninsured_in_last_year_no_answer                    0
# uninsured_in_last_year_yes                          0
# lifetime_cigarette_smoker_yes                       0
# current_cigarette_smoker_yes                        0
# dtype: int64

# %%
# fit_transform the training data, but just transform the testing data
imp = IterativeImputer(random_state=rs)
X_train_imputed = pd.DataFrame(imp.fit_transform(X_train, y_train), 
                               columns=X_train.columns, index=X_train.index)

X_test_imputed = pd.DataFrame(imp.transform(X_test), columns=X_test.columns, index=X_test.index)

display(X_train_imputed.head())
display(y_train.head())
# Out:
#         weight_kg  ...  current_cigarette_smoker_yes
# SEQN               ...
# 102783       64.8  ...                           0.0
# 99996        84.6  ...                           1.0
# 99721        74.8  ...                           0.0
# 97169        87.9  ...                           0.0
# 94465       106.2  ...                           0.0
#
# [5 rows x 47 columns]
# SEQN
# 102783    1
# 99996     1
# 99721     0
# 97169     1
# 94465     0
# Name: diagnosis, dtype: int64

# %%
X_train_imputed.isna().sum()
# Out:
# weight_kg                                        0
# height_cm                                        0
# BMI                                              0
# waist_circumference_cm                           0
# hip_circumference_cm                             0
# age                                              0
# household_size                                   0
# annual_household_income                          0
# income_poverty_ratio                             0
# sedentary_minsperday                             0
# vigorous_activity_minsperweek                    0
# moderate_activity_minsperweek                    0
# avg_pulse                                        0
# gender_male                                      0
# race_black                                       0
# race_hispanic                                    0
# race_mexican_american                            0
# race_other                                       0
# race_white                                       0
# veteran_status_yes                               0
# country_of_birth_usa                             0
# citizen_status_no_answer                         0
# citizen_status_non_citizen                       0
# education_highschool_grad                        0
# education_no_diploma                             0
# education_some_college                           0
# marital_status_married or living with partner    0
# marital_status_never married                     0
# marital_status_no_answer                         0
# marital_status_widowed                           0
# coverage_status_no_answer                        0
# coverage_status_uninsured                        0
# covered_private_yes                              0
# covered_medicare_yes                             0
# covered_medigap_yes                              0
# covered_medicaid_yes                             0
# covered_chip_yes                                 0
# covered_military_yes                             0
# covered_state_yes                                0
# covered_other_gov_yes                            0
# covered_single_service_yes                       0
# prescription_coverage_no_answer                  0
# prescription_coverage_yes                        0
# uninsured_in_last_year_no_answer                 0
# uninsured_in_last_year_yes                       0
# lifetime_cigarette_smoker_yes                    0
# current_cigarette_smoker_yes                     0
# dtype: int64

# %%
X_test_imputed.head()
# Out:
#         weight_kg  ...  current_cigarette_smoker_yes
# SEQN               ...
# 98959        72.4  ...                           0.0
# 102761       71.6  ...                           0.0
# 100216       52.8  ...                           0.0
# 99151        69.2  ...                           0.0
# 99679        90.1  ...                           0.0
#
# [5 rows x 47 columns]

# %%
X_test_imputed.isna().sum()
# Out:
# weight_kg                                        0
# height_cm                                        0
# BMI                                              0
# waist_circumference_cm                           0
# hip_circumference_cm                             0
# age                                              0
# household_size                                   0
# annual_household_income                          0
# income_poverty_ratio                             0
# sedentary_minsperday                             0
# vigorous_activity_minsperweek                    0
# moderate_activity_minsperweek                    0
# avg_pulse                                        0
# gender_male                                      0
# race_black                                       0
# race_hispanic                                    0
# race_mexican_american                            0
# race_other                                       0
# race_white                                       0
# veteran_status_yes                               0
# country_of_birth_usa                             0
# citizen_status_no_answer                         0
# citizen_status_non_citizen                       0
# education_highschool_grad                        0
# education_no_diploma                             0
# education_some_college                           0
# marital_status_married or living with partner    0
# marital_status_never married                     0
# marital_status_no_answer                         0
# marital_status_widowed                           0
# coverage_status_no_answer                        0
# coverage_status_uninsured                        0
# covered_private_yes                              0
# covered_medicare_yes                             0
# covered_medigap_yes                              0
# covered_medicaid_yes                             0
# covered_chip_yes                                 0
# covered_military_yes                             0
# covered_state_yes                                0
# covered_other_gov_yes                            0
# covered_single_service_yes                       0
# prescription_coverage_no_answer                  0
# prescription_coverage_yes                        0
# uninsured_in_last_year_no_answer                 0
# uninsured_in_last_year_yes                       0
# lifetime_cigarette_smoker_yes                    0
# current_cigarette_smoker_yes                     0
# dtype: int64

# %% [markdown]
# ## Class Balance

# %%
# checking for class imbalance in the target feature
print(y_train.value_counts())
print('*****'*15)
print(y_train.value_counts(normalize=True).round(3))
# Out:
# 0    2888
# 1    1872
# Name: diagnosis, dtype: int64
# ***************************************************************************
# 0    0.607
# 1    0.393
# Name: diagnosis, dtype: float64

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(n_jobs=3)
X_train_bal, y_train_bal = smote.fit_sample(X_train_imputed, y_train)

# %%
display(X_train_bal.head())
display(y_train_bal.head())
# Out:
#    weight_kg  ...  current_cigarette_smoker_yes
# 0       64.8  ...                           0.0
# 1       84.6  ...                           1.0
# 2       74.8  ...                           0.0
# 3       87.9  ...                           0.0
# 4      106.2  ...                           0.0
#
# [5 rows x 47 columns]
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# Name: diagnosis, dtype: int64

# %%
print(y_train_bal.value_counts())
print('*****'*15)
print(y_train_bal.value_counts(normalize=True).round(3))
# Out:
# 1    2888
# 0    2888
# Name: diagnosis, dtype: int64
# ***************************************************************************
# 1    0.5
# 0    0.5
# Name: diagnosis, dtype: float64

# %%
# reset variables to simplify model process on unscaled data
X_train = X_train_bal.copy()
y_train = pd.DataFrame(y_train_bal.copy())
X_test = X_test_imputed.copy()
# y_test hasn't changed

# %%
display(X_train.head())
display(y_train.head())
# Out:
#    weight_kg  ...  current_cigarette_smoker_yes
# 0       64.8  ...                           0.0
# 1       84.6  ...                           1.0
# 2       74.8  ...                           0.0
# 3       87.9  ...                           0.0
# 4      106.2  ...                           0.0
#
# [5 rows x 47 columns]
#    diagnosis
# 0          1
# 1          1
# 2          0
# 3          1
# 4          0

# %%
display(X_test.head())
display(y_test.head())
# Out:
#         weight_kg  ...  current_cigarette_smoker_yes
# SEQN               ...
# 98959        72.4  ...                           0.0
# 102761       71.6  ...                           0.0
# 100216       52.8  ...                           0.0
# 99151        69.2  ...                           0.0
# 99679        90.1  ...                           0.0
#
# [5 rows x 47 columns]
# SEQN
# 98959     1
# 102761    0
# 100216    0
# 99151     0
# 99679     0
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## Normalize Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
# fit transform on train data
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)

# just transform on test data
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %% [markdown]
# # Classification Models
#
# There are many modeling algorithms available, each with their strengths and weaknesses. Each model will be fit to the training sample, then validated on the testing sample. Key metrics will be captured along the way in a summary dataframe to compare and contrast performance. A custom function has been written to quickly evaluate each model.
#
# **Recall** is the primary metric for evaluating this particular model as this represents, *out of all the true diabetic/prediabetic people, how often did the model predict correctly.*
# - The downside of missing an at-risk person is that maybe they won't get the preventative care or health information they need, and they end up developing diabetes or progressing from prediabetic to diabetic.
# - For stakeholders, this means their program did not reach the population it would most help, which translates into both public health and monetary loss in the long term (i.e., more claims to insurance companies, increased hospital utilization, etc.)
# - For the individual, this relates to missed opportunity to participate in a program that may have built health literacy and provided them the support they needed to reverse prediabetes or manage diabets. This can translate to lower quality of life, greater personal health expenses, and even loss of life.
#
# **Accuracy** is a more general metric of the model's holistic performance, representing the *percentage of predictions the model gets correct.* While this metric will be looked at, it will not be the deciding evaluation metric.
#
# **Precision** is a metric to pay less attention to, as this represents *how often the model guessed someone is diabetic/prediabetic and the person truly is diabetic/prediabetic.*
# - The downside of getting a diabetic prediction wrong is that someone not at risk for diabetes/prediabetes may be targeted for a program.
# - For the stakeholder, this just means they might spend attitional resources targeting someone who doesn't truly NEED their programs. Total monetary impact could be calculated by multiplying the per-person spend on advertising/outreach by the number of "false negatives" the model predicts.
# - For the person, there is no downside to having access to health and wellness programs!
#
# **F1 Score** is a metric that combines precision and recall, also called *the harmonic mean of precision and recall.*

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix, confusion_matrix
from sklearn.metrics import accuracy_score, roc_curve, auc, f1_score, recall_score

# %%
model_stats = pd.DataFrame(columns=['Model', 'Label', 'Train Recall', 'Test Recall',
                                    'Train AUC', 'Test AUC', 
                                    'Train Accuracy', 'Test Accuracy'])

# %%
def check_fit(model, X_train, y_train, X_test, y_test):
    '''
    Fits model to training data, then looks for overfitting by comparing 
    accuracy and F1 score of the training sample to the same metrics of the testing sample.
    
    Inputs:
    model (unfit)
    X_train - pandas dataframe comprised of training predictors
    y_train - pandas dataframe comprised of training target
    X_test - pandas dataframe comprised of testing predictors
    y_test - pandas dataframe comprised of testing target
    
    Returns:
    Dataframe with columns for evaluation metrics, rows for the training and testing samples
    '''
    model.fit(X_train, y_train)
    stats = pd.DataFrame(index=['Training', 'Testing'], columns=['Accuracy', 'F1 Score'])
    y_train_pred = model.predict(X_train)
    stats['Accuracy']['Training'] = accuracy_score(y_train, y_train_pred)
    stats['F1 Score']['Training'] = f1_score(y_train, y_train_pred)
    y_test_pred = model.predict(X_test)
    stats['Accuracy']['Testing'] = accuracy_score(y_test, y_test_pred)
    stats['F1 Score']['Testing'] = f1_score(y_test, y_test_pred)
    return stats

def plot_roc(fpr_test, tpr_test):
    '''
    Plots the receiver operating curve for a binary classification model
    
    Inputs:
    fpr_test - false positive rate associated with a model
    tpr_test - true positive rate associated with a model
    
    Returns:
    matplotlib plot showing a model's receiver operating curve (ROC) compared to a dummy binary model
    '''
    test_auc = auc(fpr_test, tpr_test)
    print('AUC: {}'.format(test_auc))
    plt.figure(figsize=(6,4))
    plt.plot(fpr_test, tpr_test, color='darkorange', label='ROC curve')
    plt.plot([0,1], [0,1], color='navy', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()

def evaluate_classifier(model, X_train, y_train, X_test, y_test, 
                        cmap='Blues', model_stats=None, track=True, label=''):
    '''
    Overall evaluation of a model's performance using multiple metrics and visualizations.
    Can be used as part of an iterative modeling process to capture metrics from multiple models
    and compare easily.
    
    Inputs:
    model - unfit model object with any parameters already passed
    X_train - pandas dataframe comprised of training predictors
    y_train - pandas dataframe comprised of training target
    X_test - pandas dataframe comprised of testing predictors
    y_test - pandas dataframe comprised of testing target
    *
    cmap='Blues' - color scheme for resulting confusion matrix *must be a sequential colormap 
        recognized by matplotlib https://matplotlib.org/stable/tutorials/colors/colormaps.html
    model_stats=None - dataframe in which to capture summary metrics. If None, the function will
        create a new dataframe.
    track=True - boolean, whether to write and return the summary dataframe. If True, 
        summary metrics will be appended to the dataframe passed in model_stats parameter. 
        If False, summary metrics will not be captured or returned.
    label='' = optional additional label to include in model_stats summary dataframe to 
        differentiate this model from others in your iterative process
        
    Returns:
    Model fit to training data and evaluation metrics including accuracy, precision, recall, F1-score,
    confusion matrix, receiver operating curve.
    If track=True, model_stats dataframe is returned.
    '''
    model.fit(X_train, y_train)
    
    print('CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data')
    display(check_fit(model, X_train, y_train, X_test, y_test))
    print('*****'*15)
    
    y_test_pred = model.predict(X_test)
    test_acc = accuracy_score(y_test, y_test_pred)
    y_train_pred = model.predict(X_train)
    train_acc = accuracy_score(y_train, y_train_pred)
    
    print('\nCHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy\n')
    print(classification_report(y_test, y_test_pred))
    plot_confusion_matrix(model, X_test, y_test, normalize='all', cmap=cmap)
    print('*****'*15)
    
    print('\nCHECK Test ROC CURVE - seek to maximize area under the curve\n')
    y_score_train = model.predict_proba(X_train)
    fpr_train, tpr_train, thresholds_train = roc_curve(y_train, y_score_train[:,1])
    train_auc = auc(fpr_train, tpr_train)
    
    y_score_test = model.predict_proba(X_test)
    fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_score_test[:,1])
    test_auc = auc(fpr_test, tpr_test)
    
    plot_roc(fpr_test, tpr_test)
    
    tn, fp, fn, tp = confusion_matrix(y_test, y_test_pred).ravel()
    fnr = fn/(fn+tp)

    if model_stats is None:
        model_stats = pd.DataFrame(columns=['Model', 'Label', 'Train Recall', 'Test Recall',
                                            'False Negatives',
                                            'Train AUC', 'Test AUC', 
                                            'Train Accuracy', 'Test Accuracy'])
    
    stats_dict = {}
    stats_dict['Model'] = str(model)
    stats_dict['Label'] = label
    try:
        stats_dict['Train AUC'] = train_auc.round(4)
    except:
        stats_dict['Train AUC'] = 'could not compute'
    try:
        stats_dict['Test AUC'] = test_auc.round(4)
    except:
        stats_dict['Test AUC'] = 'could not compute'
    try:
        stats_dict['Train Accuracy'] = train_acc.round(4)
    except:
        stats_dict['Train Accuracy'] = 'could not compute'
    try:
        stats_dict['Test Accuracy'] = test_acc.round(4)
    except:
        stats_dict['Test Accuracy'] = 'could not compute'
    try:
        stats_dict['Train Recall'] = recall_score(y_train, y_train_pred).round(4)
    except:
        stats_dict['Train Recall'] = 'could not compute'
    try:
        stats_dict['Test Recall'] = recall_score(y_test, y_test_pred).round(4)
    except:
        stats_dict['Test Recall'] = 'could not compute'
    try:
        stats_dict['False Negatives'] = fn
    except:
        stats_dict['False Negatives'] = 'could not compute'
    
    if track:
        model_stats = model_stats.append(pd.Series(stats_dict), ignore_index=True)
        return model_stats

# %% [markdown]
# ## Dummy Model - *for comparison only*
#
# The dummy model uses simple rules (most_frequent, stratified, etc.) to make predictions. This is used as a baseline only to compare more intelligent models against.

# %%
from sklearn.dummy import DummyClassifier

# %%
dummy_clf = DummyClassifier(strategy='stratified')

# %% [markdown]
# ### Scaled data

# %%
evaluate_classifier(dummy_clf, X_train_scaled, y_train, X_test_scaled, y_test, track=False)
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.504155  0.501913
# Testing    0.49958  0.429119
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.51      0.55       719
#            1       0.40      0.50      0.44       472
#
#     accuracy                           0.50      1191
#    macro avg       0.50      0.50      0.50      1191
# weighted avg       0.52      0.50      0.51      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.5008810494802103

# %% [markdown]
# ### Unscaled data

# %%
evaluate_classifier(dummy_clf, X_train, y_train, X_test, y_test, track=False)
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.494806   0.49533
# Testing    0.50042  0.458599
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.51      0.56       719
#            1       0.42      0.53      0.47       472
#
#     accuracy                           0.52      1191
#    macro avg       0.52      0.52      0.52      1191
# weighted avg       0.54      0.52      0.53      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.4981318215035006

# %% [markdown]
# As expected, the dummy models using the stratification strategy both performed no better than random chance.

# %% [markdown]
# ## Logistic Regression
#
# The logistic regression model guesses the probability that an element belongs to the normal class or the diabetic class based on the relationships learned between the target and predictors in the training sample.

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
log_clf = LogisticRegressionCV(random_state=rs, cv=3)

# %% [markdown]
# ### Scaled data

# %%
model_stats = evaluate_classifier(log_clf, X_train_scaled, y_train, X_test_scaled, y_test, 
                                  model_stats=model_stats, label='default params, scaled data')
model_stats
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#           Accuracy  F1 Score
# Training  0.760734  0.769051
# Testing   0.753149  0.708911
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79       719
#            1       0.67      0.76      0.71       472
#
#     accuracy                           0.75      1191
#    macro avg       0.75      0.75      0.75      1191
# weighted avg       0.76      0.75      0.76      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8273850215695058
#                                           Model  ... False Negatives
# 0  LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
#
# [1 rows x 9 columns]

# %% [markdown]
# ### Unscaled data

# %%
model_stats = evaluate_classifier(log_clf, X_train, y_train, X_test, y_test, 
                                  model_stats=model_stats, label='default params, unscaled data')
model_stats
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#           Accuracy  F1 Score
# Training  0.745152  0.751854
# Testing   0.734677  0.693204
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.72      0.77       719
#            1       0.64      0.76      0.69       472
#
#     accuracy                           0.73      1191
#    macro avg       0.73      0.74      0.73      1191
# weighted avg       0.75      0.73      0.74      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8052379717592701
#                                           Model  ... False Negatives
# 0  LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1  LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
#
# [2 rows x 9 columns]

# %%
log_clf_coefs = pd.DataFrame(log_clf.coef_[0], index=X_train.columns).round(3)
print('Positively related coefficients:')
display(log_clf_coefs[log_clf_coefs[0]>=0.01].sort_values(0, ascending=False))
print('***'*15)
print('\nNegatively related coefficients:')
display(log_clf_coefs[log_clf_coefs[0]<=-.01])
# Out:
# Positively related coefficients:
#                             0
# age                     0.058
# weight_kg               0.029
# waist_circumference_cm  0.027
# *********************************************
#
# Negatively related coefficients:
#                           0
# height_cm            -0.031
# hip_circumference_cm -0.031

# %% [markdown]
# The scaled dataset performed decently well with 75% testing accuracy, and 0.82 AUC which is quite an improvement on the dummy model's 0.53.
#
# 76% of diabetic/prediabetic individuals were correctly predicted by the logistic regression model.

# %% [markdown]
# ## K-Nearest Neighbors
#
# The K-Nearest Neighbors modeling technique predicts the class of an observation by evaluating data points mathematically close to the one in question. "k" number of neighbors are found, then the average of their classes determines the model's vote for the element in question.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# using defaults of 5 nearest neighbors, uniform weights, and euclidean distance metric
knn_clf = KNeighborsClassifier()

# %% [markdown]
# ### Scaled data

# %%
model_stats = evaluate_classifier(knn_clf, X_train_scaled, y_train, X_test_scaled, y_test,
                                 model_stats=model_stats, label='defaul params, scaled data')
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# <ipython-input-165-0759a685b866>:77: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   model.fit(X_train, y_train)
# <ipython-input-165-0759a685b866>:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   model.fit(X_train, y_train)
#           Accuracy  F1 Score
# Training  0.822888  0.830433
# Testing   0.683459  0.625621
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.69      0.73       719
#            1       0.59      0.67      0.63       472
#
#     accuracy                           0.68      1191
#    macro avg       0.67      0.68      0.68      1191
# weighted avg       0.69      0.68      0.69      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.7395511656962354
#                                           Model  ... False Negatives
# 0  LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1  LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                        KNeighborsClassifier()  ...           157.0
#
# [3 rows x 9 columns]

# %% [markdown]
# ### Unscaled data

# %%
model_stats = evaluate_classifier(knn_clf, X_train, y_train, X_test, y_test,
                                 model_stats=model_stats, label='default params, unscaled data')
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# <ipython-input-165-0759a685b866>:77: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   model.fit(X_train, y_train)
# <ipython-input-165-0759a685b866>:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   model.fit(X_train, y_train)
#           Accuracy  F1 Score
# Training  0.770776  0.786589
# Testing    0.59194   0.52907
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.60      0.64       719
#            1       0.49      0.58      0.53       472
#
#     accuracy                           0.59      1191
#    macro avg       0.59      0.59      0.58      1191
# weighted avg       0.61      0.59      0.60      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.6279805402984371
#                                           Model  ... False Negatives
# 0  LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1  LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                        KNeighborsClassifier()  ...           157.0
# 3                        KNeighborsClassifier()  ...           199.0
#
# [4 rows x 9 columns]

# %%
np.asarray(y_test)
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
# look for best n_neighbors param

best_k = 0
best_score = 0.0
for k in range(1, 25):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, np.asarray(y_train).reshape(len(y_train), ))
    preds = knn.predict(X_test_scaled)
    recall = recall_score(y_test, preds)
    if recall > best_score:
        best_k = k
        best_score = recall

# %%
print(f'Best K: {best_k}')
print(f'Recall Score: {best_score}')
# Out:
# Best K: 23
# Recall Score: 0.7542372881355932

# %%
knn_clf2 = KNeighborsClassifier(n_neighbors=23)

# %%
model_stats = evaluate_classifier(knn_clf2, X_train_scaled, y_train, X_test_scaled, y_test,
                                 model_stats=model_stats, label='k=23, scaled data')
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# <ipython-input-165-0759a685b866>:77: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   model.fit(X_train, y_train)
# <ipython-input-165-0759a685b866>:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   model.fit(X_train, y_train)
#           Accuracy  F1 Score
# Training  0.758137  0.774641
# Testing   0.707809  0.671698
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74       719
#            1       0.61      0.75      0.67       472
#
#     accuracy                           0.71      1191
#    macro avg       0.71      0.72      0.70      1191
# weighted avg       0.73      0.71      0.71      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.7747857782701963
#                                           Model  ... False Negatives
# 0  LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1  LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                        KNeighborsClassifier()  ...           157.0
# 3                        KNeighborsClassifier()  ...           199.0
# 4          KNeighborsClassifier(n_neighbors=23)  ...           116.0
#
# [5 rows x 9 columns]

# %% [markdown]
# The K-Nearest Neighbors model did not do as well as the logistic regression, though it did improve quite a bit by finding the optimal k-value.

# %% [markdown]
# ## Decision Tree
#
# The decision tree classification method selects the feature that best splits the sample space in two, creates two (or more) branches based on this feature, then continues branching and splitting until the dataset has been cleanly partitioned (or until max_depth or min_samples_split parameters, if set).
#
# Using ensemble methods, a "random forest" of decision trees can be created which uses the laws of probability and central limit theorem to reach a consensus prediction based on the combination of multiple models trained on different sample splits.
#
# Decision trees do not require scaled data, so these models are only run using the unscaled samples.

# %% [markdown]
# ### Single Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
# first use default params of gini impurity, no max depth, 2 min samples split, 
    # 1 min samples leaf, no max features, and no max leaf nodes
dt_clf = DecisionTreeClassifier(random_state=rs)

# %%
model_stats = evaluate_classifier(dt_clf, X_train, y_train, X_test, y_test,
                                 model_stats=model_stats, label='default params, unscaled')
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#          Accuracy  F1 Score
# Training        1         1
# Testing   0.65911  0.575314
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.72       719
#            1       0.57      0.58      0.58       472
#
#     accuracy                           0.66      1191
#    macro avg       0.64      0.65      0.65      1191
# weighted avg       0.66      0.66      0.66      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.6459728082789186
#                                           Model  ... False Negatives
# 0  LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1  LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                        KNeighborsClassifier()  ...           157.0
# 3                        KNeighborsClassifier()  ...           199.0
# 4          KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5      DecisionTreeClassifier(random_state=610)  ...           197.0
#
# [6 rows x 9 columns]

# %% [markdown]
# The decision tree was quite overfit, as decision trees with no max features or max depth parameters tend to be.
#
# A grid search can help find the best combination of parameters to use.

# %%
dt_clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': 610,
#  'splitter': 'best'}

# %%
dt_clf.get_depth()
# Out:
# 27

# %%
dt_clf.get_n_leaves()
# Out:
# 879

# %%
pd.DataFrame(dt_clf.feature_importances_, index=X_train.columns).sort_values(0, ascending=False).reset_index()
# Out:
#                                             index         0
# 0                                             age  0.258404
# 1                          waist_circumference_cm  0.105622
# 2                                       avg_pulse  0.056084
# 3                                             BMI  0.054893
# 4                            hip_circumference_cm  0.044729
# 5                                       height_cm  0.044494
# 6                                       weight_kg  0.042644
# 7                            income_poverty_ratio  0.039875
# 8                   moderate_activity_minsperweek  0.038812
# 9                            sedentary_minsperday  0.034900
# 10                                     race_white  0.033732
# 11                                 household_size  0.028198
# 12                        annual_household_income  0.026133
# 13                                    gender_male  0.023201
# 14                  vigorous_activity_minsperweek  0.018949
# 15                         education_some_college  0.016148
# 16                                     race_black  0.014409
# 17                           country_of_birth_usa  0.012375
# 18                            covered_private_yes  0.009651
# 19                           covered_medicaid_yes  0.007368
# 20                           covered_medicare_yes  0.007275
# 21                  lifetime_cigarette_smoker_yes  0.006657
# 22                      education_highschool_grad  0.006530
# 23                                  race_hispanic  0.006258
# 24                      prescription_coverage_yes  0.005273
# 25  marital_status_married or living with partner  0.005259
# 26                             veteran_status_yes  0.005198
# 27                           education_no_diploma  0.004729
# 28                          race_mexican_american  0.004474
# 29                   marital_status_never married  0.004220
# 30                   current_cigarette_smoker_yes  0.004091
# 31                              covered_state_yes  0.004028
# 32                     covered_single_service_yes  0.003668
# 33                                     race_other  0.003654
# 34                     citizen_status_non_citizen  0.003195
# 35                     uninsured_in_last_year_yes  0.002227
# 36                prescription_coverage_no_answer  0.002164
# 37                      coverage_status_no_answer  0.002126
# 38                           covered_military_yes  0.002089
# 39                            covered_medigap_yes  0.001560
# 40                         marital_status_widowed  0.001132
# 41               uninsured_in_last_year_no_answer  0.001066
# 42                          covered_other_gov_yes  0.001050
# 43                               covered_chip_yes  0.000940
# 44                      coverage_status_uninsured  0.000517
# 45                       marital_status_no_answer  0.000000
# 46                       citizen_status_no_answer  0.000000

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score

# %%
dt_param_grid = {'criterion': ['entropy', 'gini'],
                'max_depth': [None, 5, 10, 15, 20],
                'min_samples_leaf': [1, 2, 3, 4],
                'max_features': [None, 5, 10, 15, 20]}

# %%
dt_grid_search = GridSearchCV(dt_clf, dt_param_grid, cv=3, return_train_score=True)

# %%
model_stats = evaluate_classifier(dt_grid_search, X_train, y_train, X_test, y_test,
                                 model_stats=model_stats, label='unscaled')
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.753463  0.779498
# Testing   0.718724   0.70116
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.64      0.73       719
#            1       0.61      0.83      0.70       472
#
#     accuracy                           0.72      1191
#    macro avg       0.73      0.74      0.72      1191
# weighted avg       0.76      0.72      0.72      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.7833914806345914

# %%
model_stats
# Out:
#                                                Model  ... False Negatives
# 0       LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1       LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                             KNeighborsClassifier()  ...           157.0
# 3                             KNeighborsClassifier()  ...           199.0
# 4               KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5           DecisionTreeClassifier(random_state=610)  ...           197.0
# 6  GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
#
# [7 rows x 9 columns]

# %%
dt_grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': None,
#  'min_samples_leaf': 3}

# %%
dt_clf2 = DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features=20, min_samples_leaf=4, 
                                random_state=rs)

# %% [markdown]
# ### Bagged Trees

# %%
from sklearn.ensemble import BaggingClassifier

# %%
rf_clf = BaggingClassifier(base_estimator=dt_clf2, n_estimators=25, random_state=rs)

# %%
model_stats = evaluate_classifier(rf_clf, X_train, y_train, X_test, y_test,
                                 model_stats=model_stats, 
                                  label='25 bagged trees with base estimator=gridsearch best params')
model_stats
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#           Accuracy  F1 Score
# Training  0.783934   0.79276
# Testing   0.741394  0.695652
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       719
#            1       0.65      0.75      0.70       472
#
#     accuracy                           0.74      1191
#    macro avg       0.73      0.74      0.74      1191
# weighted avg       0.75      0.74      0.74      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8069971240659108
#                                                Model  ... False Negatives
# 0       LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1       LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                             KNeighborsClassifier()  ...           157.0
# 3                             KNeighborsClassifier()  ...           199.0
# 4               KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5           DecisionTreeClassifier(random_state=610)  ...           197.0
# 6  GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7  BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
#
# [8 rows x 9 columns]

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf2 = RandomForestClassifier(n_estimators=50, criterion='entropy', max_depth=5, max_features=20,
                                min_samples_leaf=4, random_state=rs)

# %%
model_stats = evaluate_classifier(rf_clf2, X_train, y_train, X_test, y_test,
                                 model_stats=model_stats, label='RF with gridsearch best params, 50 trees')
# Out:
# <ipython-input-165-0759a685b866>:77: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# <ipython-input-165-0759a685b866>:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
#           Accuracy  F1 Score
# Training  0.782548  0.792122
# Testing   0.741394  0.696252
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.77       719
#            1       0.65      0.75      0.70       472
#
#     accuracy                           0.74      1191
#    macro avg       0.73      0.74      0.74      1191
# weighted avg       0.75      0.74      0.74      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8060586148369911

# %% [markdown]
# The random forest model is the best model so far, with only a 9.3% false negative rate and .76 recall score on testing data. It doesn't seem too overfit since the testing data is doing comparable to the training data.

# %% [markdown]
# ## Boosting Ensemble Methods
#
# Boosting ensemble methods are similar to random forests in that they leverage many individual models to come to one overall prediction. Where random forests are comprised on many decision trees which are individually viable models, boosting methods train many decision trees with a max_depth=1, meaning they are optimized on only one split. Each subsequent model focuses on optimizing what the last model got wrong by weighting incorrectly classified instances higher.

# %% [markdown]
# ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
# using default params of n_estimators=50 and learning_rate=1
ab_clf = AdaBoostClassifier(random_state=rs)

# %%
model_stats = evaluate_classifier(ab_clf, X_train, y_train, X_test, y_test,
                                 model_stats=model_stats, label='default params, unscaled')
model_stats
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#           Accuracy  F1 Score
# Training  0.781163  0.784521
# Testing   0.744752  0.675906
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79       719
#            1       0.68      0.67      0.68       472
#
#     accuracy                           0.74      1191
#    macro avg       0.73      0.73      0.73      1191
# weighted avg       0.74      0.74      0.74      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8102075033591852
#                                                Model  ... False Negatives
# 0       LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1       LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                             KNeighborsClassifier()  ...           157.0
# 3                             KNeighborsClassifier()  ...           199.0
# 4               KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5           DecisionTreeClassifier(random_state=610)  ...           197.0
# 6  GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7  BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8  RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9               AdaBoostClassifier(random_state=610)  ...           155.0
#
# [10 rows x 9 columns]

# %% [markdown]
# ### GradientBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# using default params of learning_rate=1.0, n_estimators=100, criterion='friendman_mse'
gb_clf = GradientBoostingClassifier(random_state=rs)

# %%
model_stats = evaluate_classifier(gb_clf, X_train, y_train, X_test, y_test,
                                 model_stats=model_stats, label='default params, unscaled data')
model_stats
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#           Accuracy  F1 Score
# Training  0.817867  0.820845
# Testing   0.736356  0.674274
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78       719
#            1       0.66      0.69      0.67       472
#
#     accuracy                           0.74      1191
#    macro avg       0.73      0.73      0.73      1191
# weighted avg       0.74      0.74      0.74      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8173325121991466
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
#
# [11 rows x 9 columns]

# %% [markdown]
# ### XGBoost - unscaled

# %%
from xgboost import XGBClassifier

# %%
xgb_clf = XGBClassifier(random_state=rs)

# %%
model_stats = evaluate_classifier(xgb_clf, X_train, y_train, X_test, y_test,
                                 model_stats=model_stats, label='default params, unscaled')
model_stats
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.995672  0.995675
# Testing   0.735516  0.663821
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.78       719
#            1       0.67      0.66      0.66       472
#
#     accuracy                           0.74      1191
#    macro avg       0.72      0.72      0.72      1191
# weighted avg       0.73      0.74      0.74      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.805706489710285
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
# 11  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           161.0
#
# [12 rows x 9 columns]

# %% [markdown]
# XGBoost model is quite overfit, and both AdaBoost and GradientBoosting classifiers are good but not as good as the tuned random forest in recall score.

# %% [markdown]
# ## Support Vector Machine
#
# Support vector machines maximize the decision boundary between points to balance underfitting and overfitting. The slack parameter determines the balance between prioritizing accuracy or maximum margin.

# %%
from sklearn.svm import SVC

# %%
svc_clf = SVC(probability=True, random_state=rs)

# %%
model_stats = evaluate_classifier(svc_clf, X_train_scaled, y_train, X_test_scaled, y_test,
                                 model_stats=model_stats, label='scaled')
model_stats
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#           Accuracy  F1 Score
# Training  0.838989   0.84572
# Testing   0.742233  0.693918
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78       719
#            1       0.66      0.74      0.69       472
#
#     accuracy                           0.74      1191
#    macro avg       0.73      0.74      0.74      1191
# weighted avg       0.75      0.74      0.74      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.815318474340539
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
# 11  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           161.0
# 12            SVC(probability=True, random_state=610)  ...           124.0
#
# [13 rows x 9 columns]

# %% [markdown]
# # Feature Re-Selection
#
# The first dataset had a lot of features, many of which the best-performing model - tuned random forest - didn't use since the max_features parameter is set to 20.
#
# The next iterations will limit the feature set and rerun models to see if performance improves without as much noise in the predictor set.
#
#
# ## Preprocessing

# %%
# find what features the best model was using
dt_clf2_features = pd.DataFrame(dt_clf2.fit(X_train, y_train).feature_importances_, index=X_train.columns)
dt_clf2_features[dt_clf2_features[0]>0]
# Out:
#                                                       0
# weight_kg                                      0.007457
# height_cm                                      0.011960
# waist_circumference_cm                         0.342003
# hip_circumference_cm                           0.011225
# age                                            0.404425
# annual_household_income                        0.003197
# race_black                                     0.028192
# race_white                                     0.016992
# country_of_birth_usa                           0.014471
# citizen_status_non_citizen                     0.011831
# education_no_diploma                           0.059397
# marital_status_married or living with partner  0.072080
# covered_medicare_yes                           0.016770

# %%
mega_df.head()
# Out:
#        diagnosis  weight_kg  ...  ecig_smoker  smokeless_tobacco_user
# SEQN                         ...
# 93705          1       79.5  ...          NaN                     NaN
# 93706          0       66.3  ...          NaN                     NaN
# 93707          0       45.4  ...          NaN                     NaN
# 93708          1       53.5  ...          NaN                     NaN
# 93709          1       88.8  ...          yes                     yes
#
# [5 rows x 37 columns]

# %%
mega_df.columns
# Out:
# Index(['diagnosis', 'weight_kg', 'height_cm', 'BMI', 'waist_circumference_cm',
#        'hip_circumference_cm', 'gender', 'age', 'race', 'veteran_status',
#        'country_of_birth', 'citizen_status', 'education', 'marital_status',
#        'household_size', 'annual_household_income', 'income_poverty_ratio',
#        'coverage_status', 'covered_private', 'covered_medicare',
#        'covered_medigap', 'covered_medicaid', 'covered_chip',
#        'covered_military', 'covered_state', 'covered_other_gov',
#        'covered_single_service', 'prescription_coverage',
#        'uninsured_in_last_year', 'sedentary_minsperday',
#        'vigorous_activity_minsperweek', 'moderate_activity_minsperweek',
#        'avg_pulse', 'lifetime_cigarette_smoker', 'current_cigarette_smoker',
#        'ecig_smoker', 'smokeless_tobacco_user'],
#       dtype='object')

# %%
# choose the unencoded columns that map to the features used in the best model
# not including height and weight, as BMI is a combination of the two
keepcols = ['diagnosis', 'BMI', 'gender', 'age', 'race',  
            'waist_circumference_cm', 'country_of_birth', 'citizen_status',
            'education', 'marital_status', 'coverage_status', 'avg_pulse']

len(keepcols)
# Out:
# 12

# %%
mega_df2 = mega_df[keepcols]
y2 = mega_df2['diagnosis']
X2 = mega_df2.drop(columns='diagnosis')

# %%
# encode categorical columns
X2 = pd.get_dummies(X2, drop_first=True, dtype='float')
X2.head()
# Out:
#         BMI   age  ...  coverage_status_no_answer  coverage_status_uninsured
# SEQN               ...
# 93705  31.7  66.0  ...                        0.0                        0.0
# 93706  21.5  18.0  ...                        0.0                        0.0
# 93707  18.1   NaN  ...                        0.0                        0.0
# 93708  23.7  66.0  ...                        0.0                        0.0
# 93709  38.9  75.0  ...                        0.0                        0.0
#
# [5 rows x 22 columns]

# %%
# Train test split
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=.2, random_state=rs)

# %%
# impute nulls
X2_train_imputed = pd.DataFrame(imp.fit_transform(X2_train, y2_train), 
                               columns=X2_train.columns, index=X2_train.index)

X2_test_imputed = pd.DataFrame(imp.transform(X2_test), columns=X2_test.columns, 
                              index=X2_test.index)

display(X2_train_imputed.head())
display(X2_test_imputed.head())
# Out:
#          BMI   age  ...  coverage_status_no_answer  coverage_status_uninsured
# SEQN                ...
# 102783  26.4  52.0  ...                        0.0                        0.0
# 99996   31.4  51.0  ...                        0.0                        0.0
# 99721   24.7  20.0  ...                        0.0                        0.0
# 97169   33.0  67.0  ...                        0.0                        1.0
# 94465   30.9  31.0  ...                        0.0                        0.0
#
# [5 rows x 22 columns]
#          BMI   age  ...  coverage_status_no_answer  coverage_status_uninsured
# SEQN                ...
# 98959   26.7  75.0  ...                        0.0                        0.0
# 102761  26.2  25.0  ...                        0.0                        0.0
# 100216  21.2  42.0  ...                        0.0                        0.0
# 99151   26.3  22.0  ...                        0.0                        0.0
# 99679   30.1  61.0  ...                        0.0                        0.0
#
# [5 rows x 22 columns]

# %%
# balance classes
y2_train.value_counts(normalize=True)
# Out:
# 0    0.606723
# 1    0.393277
# Name: diagnosis, dtype: float64

# %%
# balance classes
X2_train_bal, y2_train_bal = smote.fit_sample(X2_train_imputed, y2_train)

# %%
y2_train_bal.value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: diagnosis, dtype: float64

# %%
# reset variables
X2_train = X2_train_bal.copy()
X2_test = X2_test_imputed.copy()
y2_train = y2_train_bal.copy()

# %%
# fit transform on train data
X2_train_scaled = pd.DataFrame(scaler.fit_transform(X2_train), columns=X2_train.columns)

# just transform on test data
X2_test_scaled = pd.DataFrame(scaler.transform(X2_test), columns=X2_test.columns)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Logistic Regression

# %%
log_clf = LogisticRegressionCV(random_state=rs, cv=3)
model_stats = evaluate_classifier(log_clf, X2_train_scaled, y2_train, X2_test_scaled, y2_test, 
                                  label='limited feature set; scaled', model_stats=model_stats)
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.748442  0.755099
# Testing   0.745592  0.701478
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       719
#            1       0.66      0.75      0.70       472
#
#     accuracy                           0.75      1191
#    macro avg       0.74      0.75      0.74      1191
# weighted avg       0.76      0.75      0.75      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8201008934254259
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
# 11  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           161.0
# 12            SVC(probability=True, random_state=610)  ...           124.0
# 13       LogisticRegressionCV(cv=3, random_state=610)  ...           116.0
#
# [14 rows x 9 columns]

# %%
model_stats = evaluate_classifier(log_clf, X2_train, y2_train, X2_test, y2_test, 
                                  label='limited feature set; unscaled', model_stats=model_stats)
model_stats
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#           Accuracy  F1 Score
# Training  0.748096  0.754513
# Testing   0.744752  0.700197
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       719
#            1       0.65      0.75      0.70       472
#
#     accuracy                           0.74      1191
#    macro avg       0.74      0.75      0.74      1191
# weighted avg       0.75      0.74      0.75      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8204662784941421
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
# 11  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           161.0
# 12            SVC(probability=True, random_state=610)  ...           124.0
# 13       LogisticRegressionCV(cv=3, random_state=610)  ...           116.0
# 14       LogisticRegressionCV(cv=3, random_state=610)  ...           117.0
#
# [15 rows x 9 columns]

# %% [markdown]
# ### K-Nearest Neighbors

# %%
model_stats = evaluate_classifier(knn_clf, X2_train_scaled, y2_train, X2_test_scaled, y2_test, 
                                  label='limited feature set; scaled', model_stats=model_stats)
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.824792  0.826356
# Testing   0.689337  0.613779
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.73      0.74       719
#            1       0.60      0.62      0.61       472
#
#     accuracy                           0.69      1191
#    macro avg       0.68      0.68      0.68      1191
# weighted avg       0.69      0.69      0.69      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.7442245585912637
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
# 11  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           161.0
# 12            SVC(probability=True, random_state=610)  ...           124.0
# 13       LogisticRegressionCV(cv=3, random_state=610)  ...           116.0
# 14       LogisticRegressionCV(cv=3, random_state=610)  ...           117.0
# 15                             KNeighborsClassifier()  ...           178.0
#
# [16 rows x 9 columns]

# %% [markdown]
# ### Boosting Ensemble Methods

# %%
# Adaboost
model_stats = evaluate_classifier(ab_clf, X2_train, y2_train, X2_test, y2_test, model_stats=model_stats,
                                 label='limited feature set; unscaled')
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.780644   0.78189
# Testing   0.738875  0.672287
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78       719
#            1       0.67      0.68      0.67       472
#
#     accuracy                           0.74      1191
#    macro avg       0.73      0.73      0.73      1191
# weighted avg       0.74      0.74      0.74      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8130716508333137
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
# 11  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           161.0
# 12            SVC(probability=True, random_state=610)  ...           124.0
# 13       LogisticRegressionCV(cv=3, random_state=610)  ...           116.0
# 14       LogisticRegressionCV(cv=3, random_state=610)  ...           117.0
# 15                             KNeighborsClassifier()  ...           178.0
# 16               AdaBoostClassifier(random_state=610)  ...           153.0
#
# [17 rows x 9 columns]

# %%
# Gradient boost
model_stats = evaluate_classifier(gb_clf, X2_train, y2_train, X2_test, y2_test, model_stats=model_stats,
                                 label='limited feature set, unscaled')
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.810249   0.81265
# Testing   0.743073  0.683884
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78       719
#            1       0.67      0.70      0.68       472
#
#     accuracy                           0.74      1191
#    macro avg       0.73      0.74      0.73      1191
# weighted avg       0.75      0.74      0.74      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8182312416020366
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
# 11  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           161.0
# 12            SVC(probability=True, random_state=610)  ...           124.0
# 13       LogisticRegressionCV(cv=3, random_state=610)  ...           116.0
# 14       LogisticRegressionCV(cv=3, random_state=610)  ...           117.0
# 15                             KNeighborsClassifier()  ...           178.0
# 16               AdaBoostClassifier(random_state=610)  ...           153.0
# 17       GradientBoostingClassifier(random_state=610)  ...           141.0
#
# [18 rows x 9 columns]

# %%
# XBG
model_stats = evaluate_classifier(xgb_clf, X2_train, y2_train, X2_test, y2_test, model_stats=model_stats,
                                 label='limited feature set, unscaled')
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.957583  0.957384
# Testing   0.731318  0.655172
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78       719
#            1       0.67      0.64      0.66       472
#
#     accuracy                           0.73      1191
#    macro avg       0.72      0.72      0.72      1191
# weighted avg       0.73      0.73      0.73      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.7966293227410952
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
# 11  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           161.0
# 12            SVC(probability=True, random_state=610)  ...           124.0
# 13       LogisticRegressionCV(cv=3, random_state=610)  ...           116.0
# 14       LogisticRegressionCV(cv=3, random_state=610)  ...           117.0
# 15                             KNeighborsClassifier()  ...           178.0
# 16               AdaBoostClassifier(random_state=610)  ...           153.0
# 17       GradientBoostingClassifier(random_state=610)  ...           141.0
# 18  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           168.0
#
# [19 rows x 9 columns]

# %% [markdown]
# ### Support Vector Machine

# %%
model_stats = evaluate_classifier(svc_clf, X2_train_scaled, y2_train, X2_test_scaled, y2_test,
                                 model_stats=model_stats, label='limited feature set SVC scaled')
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.808172  0.817523
# Testing    0.72712  0.680433
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76       719
#            1       0.63      0.73      0.68       472
#
#     accuracy                           0.73      1191
#    macro avg       0.72      0.73      0.72      1191
# weighted avg       0.74      0.73      0.73      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.8084969708399142
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
# 11  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           161.0
# 12            SVC(probability=True, random_state=610)  ...           124.0
# 13       LogisticRegressionCV(cv=3, random_state=610)  ...           116.0
# 14       LogisticRegressionCV(cv=3, random_state=610)  ...           117.0
# 15                             KNeighborsClassifier()  ...           178.0
# 16               AdaBoostClassifier(random_state=610)  ...           153.0
# 17       GradientBoostingClassifier(random_state=610)  ...           141.0
# 18  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           168.0
# 19            SVC(probability=True, random_state=610)  ...           126.0
#
# [20 rows x 9 columns]

# %%
svc_clf2 = SVC(kernel='linear', random_state=rs, probability=True)

# %%
model_stats = evaluate_classifier(svc_clf2, X2_train_scaled, y2_train, X2_test_scaled, y2_test,
                                 model_stats=model_stats, label='linear SVC limited feature set scaled')
model_stats
# Out:
# CHECK FOR OVERFITTING - seek for test data to perform almost as well as train data
#           Accuracy  F1 Score
# Training  0.750173  0.758897
# Testing   0.747271  0.707483
# ***************************************************************************
#
# CHECK ACCURACY, PRECISION, RECALL, & F1 SCORE - seek to maximize recall and accuracy
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.73      0.78       719
#            1       0.65      0.77      0.71       472
#
#     accuracy                           0.75      1191
#    macro avg       0.74      0.75      0.74      1191
# weighted avg       0.76      0.75      0.75      1191
#
# ***************************************************************************
#
# CHECK Test ROC CURVE - seek to maximize area under the curve
#
# AUC: 0.818922231913439
#                                                 Model  ... False Negatives
# 0        LogisticRegressionCV(cv=3, random_state=610)  ...           114.0
# 1        LogisticRegressionCV(cv=3, random_state=610)  ...           115.0
# 2                              KNeighborsClassifier()  ...           157.0
# 3                              KNeighborsClassifier()  ...           199.0
# 4                KNeighborsClassifier(n_neighbors=23)  ...           116.0
# 5            DecisionTreeClassifier(random_state=610)  ...           197.0
# 6   GridSearchCV(cv=3, estimator=DecisionTreeClass...  ...            79.0
# 7   BaggingClassifier(base_estimator=DecisionTreeC...  ...           120.0
# 8   RandomForestClassifier(criterion='entropy', ma...  ...           119.0
# 9                AdaBoostClassifier(random_state=610)  ...           155.0
# 10       GradientBoostingClassifier(random_state=610)  ...           147.0
# 11  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           161.0
# 12            SVC(probability=True, random_state=610)  ...           124.0
# 13       LogisticRegressionCV(cv=3, random_state=610)  ...           116.0
# 14       LogisticRegressionCV(cv=3, random_state=610)  ...           117.0
# 15                             KNeighborsClassifier()  ...           178.0
# 16               AdaBoostClassifier(random_state=610)  ...           153.0
# 17       GradientBoostingClassifier(random_state=610)  ...           141.0
# 18  XGBClassifier(base_score=0.5, booster='gbtree'...  ...           168.0
# 19            SVC(probability=True, random_state=610)  ...           126.0
# 20  SVC(kernel='linear', probability=True, random_...  ...           108.0
#
# [21 rows x 9 columns]

# %% [markdown]
# # Evaluation & Interpretation
#
# As previously mentioned, the most important evaluation metric for this report is Test Recall, or how many true positive diagnoses the model predicted in new data it hadn't seen before. As such, the next cells sort and style the iteratively populated `model_stats` dataframe to see which model performed the best.

# %%
model_stats['False Negatives Normalized'] = model_stats['False Negatives'].map(lambda x: x/y_test.shape[0])
model_stats.sort_values('Test Recall', ascending=False, inplace=True)

# %%
# sort the model_stats df that has been collecting model results iteratively by test recall
# highlight the highest values of all columns except false negatives, where lower is better
model_stats.style.highlight_max(subset=['Test Recall', 'Test AUC', 'Test Accuracy'])\
                 .highlight_min(subset=['False Negatives', 'False Negatives Normalized'])
# Out:
# <style  type="text/css" >
# #T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col3,#T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col8,#T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col9,#T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col5,#T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col7{
#             background-color:  yellow;
#         }</style><table id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Label</th>        <th class="col_heading level0 col2" >Train Recall</th>        <th class="col_heading level0 col3" >Test Recall</th>        <th class="col_heading level0 col4" >Train AUC</th>        <th class="col_heading level0 col5" >Test AUC</th>        <th class="col_heading level0 col6" >Train Accuracy</th>        <th class="col_heading level0 col7" >Test Accuracy</th>        <th class="col_heading level0 col8" >False Negatives</th>        <th class="col_heading level0 col9" >False Negatives Normalized</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234level0_row0" class="row_heading level0 row0" >6</th>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col0" class="data row0 col0" >GridSearchCV(cv=3, estimator=DecisionTreeClassifier(random_state=610),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [None, 5, 10, 15, 20],
#                          'max_features': [None, 5, 10, 15, 20],
#                          'min_samples_leaf': [1, 2, 3, 4]},
#              return_train_score=True)</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col1" class="data row0 col1" >unscaled</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col2" class="data row0 col2" >0.871500</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col3" class="data row0 col3" >0.832600</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col4" class="data row0 col4" >0.838900</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col5" class="data row0 col5" >0.783400</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col6" class="data row0 col6" >0.753500</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col7" class="data row0 col7" >0.718700</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col8" class="data row0 col8" >79.000000</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row0_col9" class="data row0 col9" >0.066331</td>
#             </tr>
#             <tr>
#                         <th id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234level0_row1" class="row_heading level0 row1" >20</th>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row1_col0" class="data row1 col0" >SVC(kernel='linear', probability=True, random_state=610)</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row1_col1" class="data row1 col1" >linear SVC limited feature set scaled</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row1_col2" class="data row1 col2" >0.786400</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row1_col3" class="data row1 col3" >0.771200</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row1_col4" class="data row1 col4" >0.811600</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row1_col5" class="data row1 col5" >0.818900</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row1_col6" class="data row1 col6" >0.750200</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row1_col7" class="data row1 col7" >0.747300</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row1_col8" class="data row1 col8" >108.000000</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row1_col9" class="data row1 col9" >0.090680</td>
#             </tr>
#             <tr>
#                         <th id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234level0_row2" class="row_heading level0 row2" >0</th>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col0" class="data row2 col0" >LogisticRegressionCV(cv=3, random_state=610)</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col1" class="data row2 col1" >default params, scaled data</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col2" class="data row2 col2" >0.796700</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col3" class="data row2 col3" >0.758500</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col4" class="data row2 col4" >0.822500</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col5" class="data row2 col5" >0.827400</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col6" class="data row2 col6" >0.760700</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col7" class="data row2 col7" >0.753100</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col8" class="data row2 col8" >114.000000</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row2_col9" class="data row2 col9" >0.095718</td>
#             </tr>
#             <tr>
#                         <th id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234level0_row3" class="row_heading level0 row3" >1</th>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row3_col0" class="data row3 col0" >LogisticRegressionCV(cv=3, random_state=610)</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row3_col1" class="data row3 col1" >default params, unscaled data</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row3_col2" class="data row3 col2" >0.772200</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row3_col3" class="data row3 col3" >0.756400</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row3_col4" class="data row3 col4" >0.801100</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row3_col5" class="data row3 col5" >0.805200</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row3_col6" class="data row3 col6" >0.745200</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row3_col7" class="data row3 col7" >0.734700</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row3_col8" class="data row3 col8" >115.000000</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row3_col9" class="data row3 col9" >0.096558</td>
#             </tr>
#             <tr>
#                         <th id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row4_col0" class="data row4 col0" >KNeighborsClassifier(n_neighbors=23)</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row4_col1" class="data row4 col1" >k=23, scaled data</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row4_col2" class="data row4 col2" >0.831400</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row4_col3" class="data row4 col3" >0.754200</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row4_col4" class="data row4 col4" >0.841200</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row4_col5" class="data row4 col5" >0.774800</td>
#                         <td id="T_9f8e3972_bd71_11eb_a05a_1e00622eb234row4_col6" class="data ro

# %% [markdown]
# Overall, the best models are consistently performing better than random chance and simple stratification models.
#
# **Test Recall**
#
# The maximum test recall of all models is consistently around .75-.8, meaning 75-80% of true diabetic/prediabetic diagnoses are correctly predicted by the model. The best performing models resulted in between 8.5-9.5% false negatives, or diabetics who were incorrectly predicted to be healthy.
#
# **Test Accuracy**
#
# The highest accuracy scores are consistently between .71 and .76, indicating that the model predicts the correct diagnosis about 71-76% of the time.

# %% [markdown]
# ## Interpreting the Support Vector Machine
#
# The linear Support Vector Machine generates coefficients for each feature which, together with a calculated intercept, draw a decision boundary that predicts the target class. These coefficients can be used to understand how the model is using each feature to come to a prediction.

# %%
svc_coefs = pd.DataFrame(svc_clf2.fit(X2_train_scaled, y2_train).coef_, 
                                columns=X2_train_scaled.columns).T
svc_coefs.rename(columns={0: 'coefficient'}, inplace=True)

# %%
def relationship(x):
    y=None
    if x>0:
        y='positive'
    elif x<0:
        y='negative'
    else:
        y='no relationship'
    return y

# %%
svc_coefs['relationship'] = svc_coefs['coefficient'].map(lambda x: relationship(x))
svc_coefs
# Out:
#                                                coefficient relationship
# BMI                                               0.264140     positive
# age                                               0.989672     positive
# waist_circumference_cm                            0.188764     positive
# avg_pulse                                         0.129765     positive
# gender_male                                       0.184611     positive
# race_black                                        0.252008     positive
# race_hispanic                                    -0.009257     negative
# race_mexican_american                             0.001708     positive
# race_other                                        0.056924     positive
# race_white                                       -0.115881     negative
# country_of_birth_usa                             -0.131779     negative
# citizen_status_no_answer                          0.009396     positive
# citizen_status_non_citizen                        0.088700     positive
# education_highschool_grad                         0.124021     positive
# education_no_diploma                              0.164799     positive
# education_some_college                            0.194054     positive
# marital_status_married or living with partner     0.289246     positive
# marital_status_never married                      0.190357     positive
# marital_status_no_answer                         -0.030688     negative
# marital_status_widowed                            0.071382     positive
# coverage_status_no_answer                         0.048375     positive
# coverage_status_uninsured                        -0.021822     negative

# %%
svc_coefs_abs = svc_coefs.iloc[svc_coefs.coefficient.abs().argsort()]

# %%
# Plot coefficients used in the best-performing model (SVC) in order of absolute value 

# Shoutout to Shane Lynn for introducing me to Patches 
# Source: https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/

colors = {'positive':'cornflowerblue', 'negative':'rebeccapurple'}
from matplotlib.patches import Patch

plt.style.use('seaborn')
plt.figure(figsize=(6,9), facecolor='white')
plt.barh(y=svc_coefs_abs.index, width=svc_coefs_abs.coefficient,
        color=svc_coefs_abs['relationship'].replace(colors))
plt.axvline(x=0, color='black')
plt.xlabel('Coefficient', fontfamily='tahoma', fontsize=12)
plt.xticks(fontsize=11, fontfamily='tahoma')
plt.ylabel('Feature', fontfamily='tahoma', fontsize=12)
plt.yticks(fontsize=11, fontfamily='tahoma')
plt.title('Support Vector Machine Model Coefficients (sorted by absolute value)', 
          fontdict = {'family': 'tahoma', 'size':16})
plt.legend(
    [Patch(facecolor=colors['positive']),
     Patch(facecolor=colors['negative'])], 
    ['positive', 'negative'],
    loc='lower right', frameon=True, facecolor='white', title='Relationship with Target',
    prop={'family': 'tahoma', 'size': 11})
plt.savefig('./images/svm_coefs.jpg', bbox_inches='tight', pad_inches=1.0)
plt.show();

# %% [markdown]
# Features with positive coefficients have a positive relationship with diagnosis. For example, higher age values have a higher probability of diabetes/prediabetes, and lower age values have a lower probability of diabetes/prediabetes.
#
# Features with negative coefficients have a negative relationship with the diagosis. For example, when a person's race is not white (race_white value is 0), there is a higher probability of diabetes/prediabetes, and when race_white value is 1, there is a lower probability of diabetes/prediabetes.
#
# *It is important to note that these are simply observations, not to imply causation. There are many factors beyond those evaluated here that together influence a person's health and circumstances.*

# %% [markdown]
# ## Interpretting the Logistic Regression
#
# Similarly, the logistic regression model is best interpreted using coefficients.

# %%
lr_coefs = pd.DataFrame(log_clf.fit(X_train_scaled, y_train).coef_, 
                                columns=X_train_scaled.columns).T

lr_coefs.rename(columns={0: 'coefficient'}, inplace=True)
# Out:
# /Users/kristincooper/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
lr_coefs['relationship'] = lr_coefs['coefficient'].map(lambda x: relationship(x))
lr_coefs
# Out:
#                                                coefficient relationship
# weight_kg                                         0.051571     positive
# height_cm                                        -0.085767     negative
# BMI                                               0.396895     positive
# waist_circumference_cm                            0.460386     positive
# hip_circumference_cm                             -0.253861     negative
# age                                               1.066038     positive
# household_size                                    0.017638     positive
# annual_household_income                           0.041981     positive
# income_poverty_ratio                              0.026323     positive
# sedentary_minsperday                             -0.017650     negative
# vigorous_activity_minsperweek                     0.019342     positive
# moderate_activity_minsperweek                    -0.051917     negative
# avg_pulse                                         0.108734     positive
# gender_male                                       0.169777     positive
# race_black                                        0.253102     positive
# race_hispanic                                    -0.073833     negative
# race_mexican_american                            -0.064685     negative
# race_other                                        0.017020     positive
# race_white                                       -0.193829     negative
# veteran_status_yes                               -0.087179     negative
# country_of_birth_usa                             -0.185539     negative
# citizen_status_no_answer                         -0.025928     negative
# citizen_status_non_citizen                        0.087042     positive
# education_highschool_grad                         0.105708     positive
# education_no_diploma                              0.168334     positive
# education_some_college                            0.133941     positive
# marital_status_married or living with partner     0.191790     positive
# marital_status_never married                      0.074179     positive
# marital_status_no_answer                         -0.025144     negative
# marital_status_widowed                            0.026605     positive
# coverage_status_no_answer                         0.034305     positive
# coverage_status_uninsured                        -0.041192     negative
# covered_private_yes                              -0.021634     negative
# covered_medicare_yes                              0.019874     positive
# covered_medigap_yes                              -0.024457     negative
# covered_medicaid_yes                             -0.026258     negative
# covered_chip_yes                                  0.005336     positive
# covered_military_yes                              0.023417     positive
# covered_state_yes                                 0.038623     positive
# covered_other_gov_yes                             0.000476     positive
# covered_single_service_yes                       -0.063722     negative
# prescription_coverage_no_answer                   0.023550     positive
# prescription_coverage_yes                        -0.001688     negative
# uninsured_in_last_year_no_answer                  0.025776     positive
# uninsured_in_last_year_yes                       -0.012217     negative
# lifetime_cigarette_smoker_yes                     0.012823     positive
# current_cigarette_smoker_yes                      0.059488     positive

# %%
lr_coefs_abs = lr_coefs.iloc[lr_coefs.coefficient.abs().argsort()]

# %%
# Plot coefficients used in the logistic regression cv in order of absolute value 

# Shoutout to Shane Lynn for introducing me to Patches 
# Source: https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/

colors = {'positive':'cornflowerblue', 'negative':'rebeccapurple'}
from matplotlib.patches import Patch

plt.style.use('seaborn')
plt.figure(figsize=(6,14), facecolor='white')
plt.barh(y=lr_coefs_abs.index, width=lr_coefs_abs.coefficient,
        color=lr_coefs_abs['relationship'].replace(colors))
plt.axvline(x=0, color='black')
plt.xlabel('Coefficient', fontfamily='tahoma', fontsize=12)
plt.xticks(fontsize=11, fontfamily='tahoma')
plt.ylabel('Feature', fontfamily='tahoma', fontsize=12)
plt.yticks(fontsize=11, fontfamily='tahoma')
plt.title('Logistic Regression Model Coefficients (sorted by absolute value)', 
          fontdict = {'family': 'tahoma', 'size':16})
plt.legend(
    [Patch(facecolor=colors['positive']),
     Patch(facecolor=colors['negative'])], 
    ['positive', 'negative'],
    loc='lower right', frameon=True, facecolor='white', title='Relationship with Target',
    prop={'family': 'tahoma', 'size': 11})
plt.savefig('./images/lr_coefs.jpg', pad_inches=3)
plt.show();

# %% [markdown]
# # Recommendations
#
# The model as-is can be used to target outreach, advertisement, and investment in preventative care, social determinants of health, health & wellness, and health literacy programs.
#
# Recommendations:
# - Target older or aging populations.
#     - Per the CDC, Type 2 diabetes most often develops in people over age 45. The model observed a similar pattern.
# - Target individuals with rising BMI, waist circumference, and average heart rates.
#     - Observing a rise in these 3 body measurements may be a good indicator of a person’s rising risk of diabetes.
# - Consult with subject matter experts before using sensitive information such as race to target populations.
#     - While this should not be considered a causal relationship, the model observed that black individuals are more likely to have diabetes and white individuals are less likely to have diabetes.  There are many underlying factors not captured in this analysis that may be more direct predictors
#
# **This model should not be used in place of physician advice and care plans.**

# %% [markdown]
# # Model Limitations & Future Enhancements
#
# **Model Limitations:**
# - Coefficients represent observed relationships of a relatively small sample and should not be considered causal. There are countless factors that influence a person's health such as family history, living environment, and many more.
# - This model is not intended to predict diabetes in children under 18 or pregnant women
# - This model was trained on a sample comprised only of individuals in the USA. Some data, notably insurance coverage status, is quite specific to this sample.
#
# **Future Enhancements:**
# - Use pipelines to standardize some of the preprocessing steps
# - Add samples to training set to improve performance.
# - Conduct additional analysis with subject matter experts to consider the underlying reasons for some observations such as the correlation between race and diagnosis.
# - Create a multivariate classifier to differentiate between prediabetes and diabetes.
# - Incorporate time-series using data from prior year NHANES.

# %% [markdown]
# # Appendix

# %% [markdown]
# ## Data reviewed but not used

# %% [markdown]
# ### Lab - Cholesterol
#
# https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/TCHOL_J.htm
#
# https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/TRIGLY_J.htm
#
# https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/HDL_J.htm
#
# A complete cholesterol test — also called a lipid panel or lipid profile — is a blood test that can measure the amount of cholesterol and triglycerides in your blood. The blood lipids measurements in NHANES include total cholesterol, high-density lipoprotein cholesterol (HDL-C), low-density lipoproteins cholesterol (LDL-C), and triglycerides.
#
# * **Total cholesterol** - sum of your blood's cholesterol content
#     * Less than 200 mg/dL - desirable
#     * 200-239 mg/dL - borderline
#     * Greater than 240 mg/dL - high
# * **High-density lipoprotein (HDL) cholesterol** - the "good" cholesterol because it helps carry away LDL cholesterol, thus keeping arteries open and your blood flowing more freely.
#     * Greater than 60 mg/dL - best
#     * 40-59 mg/dL - good
#     * Less than 50 (women) or 40 (men) - poor
# * **Low-density lipoprotein (LDL) cholesterol** "bad" cholesterol; too much of it in your blood causes the buildup of fatty deposits (plaques) in your arteries (atherosclerosis), which reduces blood flow. These plaques sometimes rupture and can lead to a heart attack or stroke.
#     * Less than 100 mg/dL - optimal
#     * 100-129 mg/dL - high for those with coronary artery disease
#     * 130-159 mg/dL - borderline
#     * Greater than 160 mg/dL - high
#     * Greater than 190 mg/dL - very high
# * **Triglycerides** - a type of fat in the blood created from calories your body doesn't need. High triglyceride levels are associated with several factors, including being overweight, eating too many sweets or drinking too much alcohol, smoking, being sedentary, or having diabetes with elevated blood sugar levels.
#     * Less than 150 mg/dL - desirable
#     * 150-199 mg/dL - borderline
#     * 200-499 mg/dL - high
#     * Greater than 500 mg/dL - very high
#
# https://www.mayoclinic.org/tests-procedures/cholesterol-test/about/pac-20384601

# %%
# chol_total = chol_total.drop(columns='LBDTCSI').rename(mapper={'LBXTC': 'cholesterol_total'}, axis=1)
# chol_total

# %%
# chol_hdl = chol_hdl.drop(columns='LBDHDDSI').rename(mapper={'LBDHDD': 'cholesterol_hdl'}, axis=1)
# chol_hdl

# %%
# chol_ldl

# %%
# chol_ldl.describe().round(1)

# %%
# chol_ldl.columns

# %%
# keepcols_chol_ldl = ['LBXTR', 'LBDLDL']
# mapper_chol_ldl = {'LBXTR': 'triglyceride', 'LBDLDL': 'cholesterol_ldl'}

# %%
# keep_chol_ldl = chol_ldl[keepcols_chol_ldl].rename(mapper=mapper_chol_ldl, axis=1)
# keep_chol_ldl

# %%
# chol1 = pd.merge(keep_chol_ldl, chol_hdl, how='outer', on='SEQN')
# chol1

# %%
# cholesterol = pd.merge(chol1, chol_total, how='outer', on='SEQN')
# cholesterol

# %% [markdown]
# ### Lab - Insulin

# %%
# insulin

# %%
# keep_insulin = pd.DataFrame(insulin['LBXIN'])
# keep_insulin.rename(mapper={'LBXIN': 'insulin'}, axis=1, inplace=True)

# %%
# keep_insulin
